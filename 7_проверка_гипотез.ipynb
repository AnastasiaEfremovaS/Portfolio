# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Анастасия, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Принятие решений в бизнесе

# %% [markdown]
# Цель проекта и краткий план работы
#
# В данном проекте нам предстоит:
# 1) выбрать гипотезу по увеличению выручки интернет-магазина
#
# 2) проверить и прокомментировать результат А/В теста
#
# Цель исследования:
#
# Выбрать наиболее перспективную из 9 гипотез по увеличению выручки интернет-магазина;
#
# Сделать вывод о результате А/В теста и принять решение о продолжении / прекращении теста.
#
# План работы:
# Часть 1
#
# приоритизация гипотез
# - познакомиться с данными - посмотреть какие предложены для анализа гипотезы
# - применить фреймворк ICE для приоритизации гипотез, отсортировать данные по убыванию приоритета
# - применить фреймворк RICE для приоритизации гипотез, отсортировать данные по убыванию приоритета
# - оценить разницу применения гипотез при методах RICE и ICE
#
# Часть 2
#
# проверка результата А/В теста
# - проверить данные (пропуски, дубликаты, типы данных); также посмотреть границы дат и уникальность пользователей в двух группах
# - проанализировать график кумулятивной выручки по группам, а также кумулятивного среднего чека по группам
# - проанализировать график относительного изменения кумулятивного среднего чека группы B к группе A и кумулятивного среднего количества заказов на посетителя по группам
# - проанализировать график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A
# - изучить точечный график количества заказов по пользователям, следать выводы и предположения
# - посчитать 95-й и 99-й перцентили количества заказов на пользователя, выбрать границу для определения аномальных пользователей
# - изучить точечный график стоимостей заказов, сделать выводы и предположения
# - посчитать 95-й и 99-й перцентили стоимости заказов, выбрать границу для определения аномальных заказов
# - посчитать и проанализировать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным
# - посчитать и проанализировать  статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным
# - посчитать и проанализировать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным
# - посчитать и проанализировать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным
#
# После анализа перечисленных факторов необходимо будет принять решение по результатам теста и объясните его.

# %% [markdown]
# ## Изучение данных о гипотезах

# %% [markdown]
# Для начала, импортируем все необходимые библиотеки для работы с гипотезами и откроем файл

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть вступление - хороший старт.
#
# Спасибо, что есть оглавление в плагине toc - по проекту удобно перемещаться:)

# %%
#Let's import all necessary libraries
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично! Спасибо, что перезапускаешь проект перед отправкой на ревью - это важный шаг, который поможет избежать простых и досадных ошибок при воспроизведении решнеия:)
# </div>

# %%
#Open file and read it

data = pd.read_csv('/datasets/hypothesis.csv')
    
pd.options.display.max_colwidth = 150
data
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Также ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Стоит настроить отображение гипотез в таблице таким образом, чтобы они отображались в своём столбце целиком - для этого можно настроить параметр `pd.options.display.max_colwidth = 150`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *спасибо, поправила!*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Итак, файл содержит 9 различных гипотез, по которым есть оценка охвата (Reach), влияния изменения на покупателей (Impact), степени уверенности в оценке изменения (Confidence) и стоимость тестирования гипотезы (Efforts).
#
# Для начала, рассчитаем фреймворк ICE для приоритизации девяти гипотез. Формула расчета: (Impact * Confidence) / Efforts

# %%
#Calculate ICE 
data['ICE'] = round(data['Impact'] * data['Confidence'] / data['Efforts'],2)
data.sort_values(by='ICE', ascending=False)
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Исходя из расчета ICE, наиболее удачные и перспективные гипотезы - девятая, первая и восьмая.
# У всех трех сравнительно небольшая стоимость проверки (Efforts), но при этом впечатляющие данные по влиянию на пользователя (Impact) и степени уверенности в этом влиянии (Confidence).
#
# Теперь рассчитаем приоритизацию с учетом охвата - оценим фреймворк RICE: (Reach * Impact * Confidence) / Efforts

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приоритизация по ICE в порядке!

# %%
#Calculate RICE 
data['RICE'] = round(data['Reach'] * data['Impact'] * data['Confidence'] / data['Efforts'],2)
data.sort_values(by='RICE', ascending=False)
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Тройка лидеров изменилась: на первом месте восьмая гипотеза, которая при расчете ICE была на третьем месте. Чемпионом она стала благодаря самому большому охвату - 10 баллов. При не особо значительных затратах на проверку, высоком охвате и довольно сильном влиянии на пользователя - эта гипотеза идеально подходит для начала работы.
# На втором месте третья гипотеза, которая не попала в тройку лидеров по ICE, но сейчас взяла серебро - т.к. охват 8 это очень высокий показатель.
# И на третьем - первая теория, тут охват ниже, но очень высокое влияние (10 баллов) и уверенность в нем (8 баллов) позволяют войти в тройку лидеров и по RICE.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Приоритизация по RICE выполнена.

# %% [markdown]
# ***Вывод по части 1:***
#
# произведен анализ гипотез и их приоритизация двумя способами -
#
# фреймворк **ICE** показал, что наиболее перспективная для проверки **гипотеза номер 9** с самыми высокими баллами (16.2)
#
# фреймворк **RICE** показал, что наиболее перспективная для проверки **гипотеза номер 8** с самыми высокими баллами (112)
#
# Разница в результатах применения фреймворков в одном показателе - охват (Reach). При расчете ICE он не учитывается, тогда как при расчете RICE охват берется в расчет. Так как у восьмой гипотезы предположительно максимальный охват (10 баллов), но кроме этого влияние и уверенность на высоком уровне, а затраты на проверку невелики - она вырывается в лидеры именно при расчете RICE.
#
# Так как фрейморк RICE более всеобъемлющий, ремоендована **гипотеза номер 8** для дальнейшей работы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пояснили различия фреймворков, а также интерпретировали различия в приоритетах гипотез - отлично!

# %% [markdown]
# ## Проверка А/В теста

# %% [markdown]
# Откроем файлы с результатами тестов и посмотрим первые 5 строк

# %%
#Open files and show first 5 rows
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')
print(orders.head(5))
print(visitors.head(5))
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %% [markdown]
# Проведем предобработку данных:
# 1. проверим данные на дубликаты
# 2. оценим пропуски и тип данных
# 3. проверим что варианты груп - это только А и В

# %%
#Check whether there are any duplicates in orders
orders.duplicated().sum()
# Out:
# 0

# %%
#Check whether there are any duplicates in visitors
visitors.duplicated().sum()
# Out:
# 0

# %%
#Observe dataframe to see omissions
print('Общая информация о таблице orders:')
print('')
print(orders.info())
print('')
print('Наличие пропусков в таблице orders:')
print('')
print(orders.isna().sum())
# Out:
# Общая информация о таблице orders:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None
#
# Наличие пропусков в таблице orders:
#
# transactionId    0
# visitorId        0
# date             0
# revenue          0
# group            0
# dtype: int64

# %%
#Observe dataframe to see omissions
print('Общая информация о таблице visitors:')
print('')
print(visitors.info())
print('')
print('Наличие пропусков в таблице visitors:')
print('')
print(visitors.isna().sum())
# Out:
# Общая информация о таблице visitors:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
# None
#
# Наличие пропусков в таблице visitors:
#
# date        0
# group       0
# visitors    0
# dtype: int64

# %%
#Check whether there are only gourp A and B in orders
orders['group'].value_counts()
# Out:
# B    640
# A    557
# Name: group, dtype: int64

# %%
#Check whether there are only gourp A and B in visitors
visitors['group'].value_counts()
# Out:
# A    31
# B    31
# Name: group, dtype: int64

# %% [markdown]
# Минимально необходимая проверка данных проведена, вот что можно заключить:
# 1. явных дубликатов в данных нет
# 2. пропуски отсутствуют, но тип данных не везде подходящий - даты в обоих датафреймах необходимо привести к типу datetime
# 3. скрытые дубликаты были возможны только в наименованиях групп, но они отсутствуют - в данных только группы А и В.
#
# Приведем даты к необходимому формату

# %%
#Change date format to datetime
orders['date'] = pd.to_datetime(orders['date'],format='%Y-%m-%d')
visitors['date'] = pd.to_datetime(visitors['date'],format='%Y-%m-%d')
#Check new date types
print(orders['date'].dtype)
print(visitors['date'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# Дополнительно проверим даты, в рамках которых заказчики посещали интернет-магазин и совершали покупки, чтобы убедиться что они соответствуют датам теста.

# %%
#check min and max date of visits
print('Начальная дата посещения интернет-магазина:')
print(visitors['date'].min())
print('')
print('Конечная дата посещения интернет-магазина:')
print(visitors['date'].max())
print('')
#check min and max date of orders
print('Дата первого заказа:')
print(orders['date'].min())
print('')
print('Дата последнего заказа:')
print(orders['date'].max())
# Out:
# Начальная дата посещения интернет-магазина:
# 2019-08-01 00:00:00
#
# Конечная дата посещения интернет-магазина:
# 2019-08-31 00:00:00
#
# Дата первого заказа:
# 2019-08-01 00:00:00
#
# Дата последнего заказа:
# 2019-08-31 00:00:00

# %% [markdown]
# Начальная дата - как визитов, так и заказов - 1 августа 2019 года, конечная дата - 31 августа 2019 года.
# Теперь у нас есть понимание сроков теста - один месяц, август 2019 года.
#
# Также проверим, что в группах А и В участвуют уникальные пользователи, т.к. для теста важно чтобы они были четко разделены: пользователи, участвующие в обеих группах, не позволят проверсти корректное сравнение среднего количества заказов на посетителя между группами.
#
# Создадим списки из уникальных пользователей в группе А и В, затем соберем новый список из пересекающихся ID пользователей, если такие есть.

# %%
#let's create two lists with unique users' ID
group_b = orders[orders['group'] == 'B']['visitorId'].unique()
group_a = orders[orders['group'] == 'A']['visitorId'].unique()
#now we use cicle to find any non-unique users in both groups
dup_visitors = []
for visitor in group_b:
    if visitor in group_a:
        dup_visitors.append(visitor)
#count number of non-unique users:
print('Количество пользователей повторяющихся в группах А и В')
print(len(dup_visitors))
# Out:
# Количество пользователей повторяющихся в группах А и В
# 58

# %% [markdown]
# Обнаружено 58 пользователей, которые присутствуют ив группе А, и в группе В.
#
# Можно удалить все записи с этими пользователями из группы В в таблице orders, но мы не можем удалить этих же пользователей из таблицы visitors - т.к. там нет данных об их ID.
#
# Оценим, какой процент составляют 58 пользователей из числа уникальных пользователей группы В.

# %%
#show the proportion of 58 in unique users of gourp B
print('Процент неуникальных пользователей среди пользователей группы B')
print(58/ orders[orders['group'] == 'B']['visitorId'].nunique())
# Out:
# Процент неуникальных пользователей среди пользователей группы B
# 0.09897610921501707

# %% [markdown]
# Около 10% пользователей в группе В участвуют также и в группе А, но если мы их удалим то исказим результаты дальнейшего анализа: отношение заказов к просмотрам будет некорректным, т.к. в таблице visitors эти пользователи останутся.
#
# Принято решение оставить данные без изменений, но иметь ввиду при описании вывода по результату теста.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Загрузили данные по покупкам и посещениям, исследовали пропуски и дубликаты, выполнили преобразование даты к нужному типу - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Пропусков действительно нет, однако их всё же стоит проверять явно с помощью метода `.isna().sum()`: в случае работы с маленькими таблицами метод `.info()` сгодится, но когда количество полей будет исчисляться десятками, глазами считать количество непустых строк будет уже трудновато:)
#
# Кроме того, получателями твоих отчётов не всегда будут технически подкованные коллеги - представители бизнес-подразделений вряд ли смогут извлечь из результатов метода `.info()` информацию о наличии пропусков.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *согласна, добавила подсчет пропусков*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# При анализе А/В тестов очень важно, помимо освещённых вопросов, узнать также и даты начала и окончания теста - не помешает в целом понимание временных рамок теста, а также в случае, если у нас есть информация о том, как тест был запроектирован, важно сравнить даты его фактического проведения с запланированными.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Очень важно также проверить, нет ли в данных пользователей, участвовавших в нескольких группах теста одновременно - это иногда случается в реальных А/В тестах из-за технических ошибок в распределяющей системе, и такие моменты важно отлавливать, потому что пользователи, участвующие в нескольких группах, не позволят проверсти корректное сравнение среднего количества заказов на посетителя между группами: если, например, пользователь, участвующий в обоих группах, совершил целевое событие, мы не сможем оценить, повлияло на это нововведение в системе, или это стандартное повдение пользователя.
#
# Если такие пользователи найдутся, тебе, как аналитику, важно сделать вывод и принять решение о том, как дальше работать с такими пользователями - удалить из данных или продолжить работать с данными с учётом таких пользователей.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Обнаружено 58 неуникальных пользователя, сделан вывод о том что удалять их нельзя - исказятся результаты, т.к. в таблице visitors мы не можем этих пользователей идентифицировать*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# В целом таких пользователей всегда стоит удалять, так как они могут давать смещение оценки целевого события: если пользователь, участвующий в обоих группах, совершил целевое событие теста, мы не сможем достоверно оценить, произошло это под влиянием нововведения, или же это его обычное поведение.
#
# Но в рамках учебного проекта можно оставить:)

# %% [markdown]
# Приступим к анализу результата А/В теста.
#
# Для начала, построим график кумулятивной выручки по группам.

# %%
# create df with unique dates and groups
datesGroups = orders[['date','group']].drop_duplicates()

# obtain aggregated orders by days 
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transactionId' : 'nunique', 'visitorId' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# obtain aggregated number of visitors by days 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# merge cumulative data into one table with clear columns' names
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Кумулятивные данные собрали - отлично!

# %%
# create df with cumulative orders and revenues by days for group A
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# create df with cumulative orders and revenues by days for group B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# build plot for group A cum. revenue
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# build plot for group B cum. revenue
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.title('Кумулятивная выручка по дням')
plt.xticks(rotation=45)
plt.xlabel("Даты")
plt.ylabel("Выручка")
plt.legend() 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Здесь и далее на графиках нужно подписать оси Х и Y.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *добавила здесь и далее*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Выручка довольно уверенно лидирует по группе В: в самом начале накопленные выручки были почти одинаковы, но начиная с 12-13 дня теста, группа В показывает хороший тренд на опережение.
#
# Однако график группы В по выручке резко растет в районе 17 августа. Это может сигнализировать о всплеске числа заказов, либо о появлении очень дорогих заказов в выборке. Такие аномалии отрицательно сказываются на анализе, поэтому позже мы их проанализируем и исключим.
#
# Построим теперь график кумулятивного среднего чека по группам А и В.

# %%
# build plot for average cumulative cheque
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.title('Кумулятивный средний чек по дням')
plt.xticks(rotation=45)
plt.legend() 
plt.xlabel("Даты")
plt.ylabel("Кумулятивный средний чек")
plt.show()

# %% [markdown]
# В отличие от выручки, кумулятивный средний чек группы В лидировал не всегда - в первой половине августа его дважды опережала группа А. Но с середины месяца чек группы В резко вырвался вперед и больше не уступал группе А.
#
# Скачок роста опять в районе 17 августа, там была какая-то большая покупка, которая сильно влияет на данные. Чуть позже мы выясним, что это.
#
# Пора построить график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# let's collect cum.data into ine dataframe
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# build plot with relation of average cum.cheques
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# add X axis
plt.axhline(y=0, color='black', linestyle='--') 
plt.title('Относительное изменение кумулятивного среднего чека по дням')
plt.xticks(rotation=45)
plt.xlabel("Даты")
plt.ylabel("Отношение выручки группы В к группе А")
plt.show()

# %% [markdown]
# График прыгает вверх и вниз, что также свидетельствует о наличии выбросов.
#
# Построим теперь график кумулятивного среднего количества заказов на посетителя по группам А и В.

# %%
# let's calculate cumulative conversion
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# separate group A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# separate group B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

#obtain min and max conversion to set y limits for plot
print('Минимальное значение конверсии')
print(cumulativeData['conversion'].min())
print('Максимальное значение конверсии')
print(cumulativeData['conversion'].max())
# Out:
# Минимальное значение конверсии
# 0.029217427214536445
# Максимальное значение конверсии
# 0.03685636856368564

# %%
# build plots
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()

# set axis scale
plt.title('Изменение кумулятивного среднего количества заказов на посетителя по дням')
plt.ylim(0.025, 0.04)
plt.xlabel("Даты")
plt.ylabel("Среднее количество заказов на посетителя")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Из графика также следует что группа В лучше группы А по отношению заказов к числу посетителей, причем на протяжении почти всего теста - с начала августа.
#
# Оценим теперь график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Этот график стоит центрировать - для этого стоит задать минимальное и максимальное значение по шкале Y в соответствии с минимальным и максимальным значением конверсии (с небольшими отступами с обоих сторон, чтобы линия не касалась границ графика в точках минимума и максимума). Это позволит более явно видеть динамику среднего количества заказов на посетителя. Для изменения минимального и максимального значения по оси Y можно использовать метод `ylim()`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *найдены минимальное и максимальное значения конверсии, добавлены в ylim. Границы были заданы у меня и ранее, но "на глазок"... )*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# build plot of cumulative conversions
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1)

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=-0.1, color='grey', linestyle='--')
plt.ylim(-0.3, 0.3)
plt.title('Относительное изменение кумулятивного среднего количества заказов на посетителя по дням')
plt.xticks(rotation=45)
plt.xlabel("Даты")
plt.ylabel("Кумулятивное среднее кол-во заказов")
plt.show()

# %% [markdown]
# В относительном измерении группа В также выигрывает, особенно в самом начале теста. Затем немного проседает, но со второй недели растет, также в конце теста демонстрирует рост.
#
# Следующим этапом построим точечный график количества заказов по пользователям, чтобы оценить выбросы о которых писали ранее.
# Для начала, соберем данные о количестве заказов по покупателям и посмотрим лидеров по кол-ву заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В этом блоке всё верно - отличная работа с кумулятивными данными!

# %%
# obtain number of orders by user and show users with max number 
ordersByUsers = (
    orders.groupby('visitorId', as_index=False)
    .agg({'transactionId': 'nunique'})
)
ordersByUsers.columns = ['userId', 'orders']
print(ordersByUsers.sort_values(by='orders', ascending=False).head(10))
# Out:
#           userId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# 744   3062433592       5
# 55     237748145       5
# 917   3803269165       5
# 299   1230306981       5
# 897   3717692402       5

# %% [markdown]
# Явно выбиваются два покупателя у которых по 11 заказов, а также еще два у которых 8 и 9 заказов.
# Далее уже много покупателей с 5 заказами, но мы пока не знаем - много это или средне.
#
# Посмотрим на точечный график.

# %%
# build scatter plot for orders number
x_values = pd.Series(range(0,len(ordersByUsers)))
plt.scatter(x_values, ordersByUsers['orders']) 
plt.title('Количество заказов по пользователям')
plt.xlabel("Количество пользователей")
plt.ylabel("Кол-во заказов")
plt.show()

# %% [markdown]
# Из графика видно, что очень много покупателей с 1-2 заказами, меньше - с 3 и более, и совсем уже аномально выглядят покупатели  с 8,9 и 11 заказами. Но чтобы убедиться в этом. нужно посчитать 95-й и 99-й перцентили количества заказов на пользователя - так мы сможем статистически подтвердить наши догадки.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали распределение количества покупок на пользователя и нашли аномальных покупателей - отлично!

# %%
 # find 95 and 99 percentile for number of orders
np.percentile(ordersByUsers['orders'], [95, 99])
# Out:
# array([2., 4.])

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Персентили посчитаны верно.

# %% [markdown]
# Не более 5% покупателей сделали 2 заказа и больше, и менее 1% сделали 4 заказа и больше.
#
# Но на графике с точками довольно много покупателей с тремя заказами, не хотелось бы исключать их из анализа.
#
# Поэтому возьмем 4 заказа как верхнюю границу для отсечения аномальных значений.
#
# Теперь посмотрим точечный график стоимостей заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Определили границу для фильтрации аномалий - отлично!

# %%
# build scatter plot for revenue
x_values = pd.Series(range(0,len(orders['revenue'])))
plt.scatter(x_values, orders['revenue']) 
plt.title('Стоимость заказов по пользователям')
plt.xlabel("Количество пользователей")
plt.ylabel("Стоимость заказа")
plt.show()

# %% [markdown]
# Довольно ровный график, если не считать двух выбросов - так что картина может сильно поменяться, если их исключить.
#
# Оценим данные в перцентилях, а также посмотрим среднюю сумму (медиану) заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали распределение стоимости заказов и нашли аномально дорогие заказы - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Как видишь, на фоне двух достаточно крупных заказов остальные, менее аномальные заказы, сбились в одну кучу на оси Х. Было бы полезно сделать такой же график, но без двух крупных покупок, чтобы исследовать распределение менее аномальных покупок.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *добавила ниже, после определения персентилей*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
 # find 95 and 99 percentile for revenue
print(np.percentile(orders['revenue'], [95, 99]))
print(orders['revenue'].median())
# Out:
# [28000.  58233.2]
# 2978.0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Персентили посчитаны верно.

# %% [markdown]
# Средний медианный заказ - около 3000, в то время как выбросы за пределами 28000 (на такую и более сумму покупают не более 5% пользователей нашего интернет-магазина) и 58000 (свыше этой суммы покупали не более 1% пользователей, и по точечному графику очевидно что это был один-единственный заказ).
#
# Для дальнейшего анализа и очистки данных от выбросов, возьмем предел в 28000.
#
# Оценим точечный график без аномально больших заказов (5% заказов свыше 28000).

# %%
# build scatter plot for revenue below 28000
orders_new = orders[orders['revenue']<28000]
# build scatter plot for revenue
x_values = pd.Series(range(0,len(orders_new['revenue'])))
plt.scatter(x_values, orders_new['revenue']) 
plt.title('Стоимость заказов по пользователям')
plt.xlabel("Количество пользователей")
plt.ylabel("Стоимость заказа")
plt.show()

# %% [markdown]
# Совсем другой вид - очевидно что больше всего заказов до 5000, но также довольно много заказов и от 5000 до 20000. Распределение равномерное, значительных перепадов или пробелов нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Определили границу для фильтрации аномалий - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь рекомендую в качестве границ аномалий брать именно расчётное значение персентиля, по двум причинам:
# - если берёшь что-то с отступом от персентиля, будет тяжелее отвечать на вопрос коллег, знакомых со статистикой, `По какому персентилю отфильтрованы аномалии` (скорее всего, для рандомного значения ты не определишь точный персентиль), а также могут быть сложности с дальнейшими статистическими расчётами, где вещи вроде степеней свободы и размера персентиля важно знать как входной параметр;
# - вопрос автоматизации - проще указать как значение `np.percentile(x)`, чем каждый раз писать переменную руками.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *поправила, оставляю 28000 по 95 персентилю*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Какой же способ оценки различия применить для того чтобы сравнить наши группы?
#
# Так как мы имеем две независимые группы (за исключением нескольких пользователей, попавших в обе группы);
# имеем количественно измеренные данные - а именно, количество заказов и выручку; но при этом не можем утверждать что наши выборки распределены нормально относительно генеральной совокупности, имеет смысл применить непараметрический критерий Манна-Уитни.
#
# Для начала, рассчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
#
# Сформулируем гипотезы.
# - Нулевая: различий в среднем количестве заказов между группами нет.
# - Альтернативная: различия в среднем между группами есть.
#
# Подготовим данные для анализа: соберем
# - количество пользователей в каждую дату по группе А и В, а также кумулятивно;
# - кол-во заказов в каждую дату по группе А и В, а также кумулятивно;
# - выручка по каждой группе ежедневно, а также кумулятивно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Гипотезы сформулировали - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Важно также указать критерий, с помощью которого мы проверяем гипотезы, а также обосновать его выбор - это обычно связано с наличием в данных каких-то особенностей и характером их распределения (про это говорилось в тренажёре).

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *добавила критерий и обосновала выбор*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заново собираются кумулятивные данные: из переменной `data` далее в расчётах мы берём только количество посетителей в зависимости от группы - эти данные у нас уже есть в переменной `visitors`. Нет большого смысла писать полотно кода и тратить ресурсы на его выполнение, если эти данные есть в исходной таблице - давай попробуем использовать исходные данные?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *удалила простыню :)*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отлично!

# %% [markdown]
# Теперь соберем данные для сравнения и вычислим p-value и относительное преимущество группы В перед группой А.

# %%
# group orders by users in groups A and B
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
ordersByUsersB.columns = ['userId', 'orders'] 
#create samples of users by groups with number of orders
sampleA = pd.concat([ordersByUsersA['orders'],pd.Series(0, index=np.arange(visitors[visitors['group'] == 'A']['visitors'].\
                                                                           sum() - len(ordersByUsersA['orders'])),\
                                                        name='orders')],axis=0)

sampleB = pd.concat([ordersByUsersB['orders'],pd.Series(0, index=np.arange(visitors[visitors['group'] == 'B']['visitors'].\
                                                                           sum() - len(ordersByUsersB['orders'])), \
                                                        name='orders')],axis=0) 
print('P-value составляет:')
print("{0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print('Относительное преимущество группы В перед группой А:')
print("{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# P-value составляет:
# 0.017
# Относительное преимущество группы В перед группой А:
# 0.138

# %% [markdown]
# Вывод: По «сырым» данным можно отвергнуть нулевую гипотезу - отличия в среднем числе заказов для групп A и B достигли статистической значимости, т.к. p-value составило 0.017 - меньше 0,05.
#
# Относительный выигрыш группы B равен 13.8% — вполне существенный отрыв.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили значимость различий среднего количества заказов на посетителя между группами на сырых данных - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# В выводе кода стоит явно подписать, какое из двух значений - `p-value`, а какое - относительная разница между сравниваемыми величинами. Замечание актуально для этой и следующих проверок.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *поправила, далее тоже поправлю*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Теперь проверим статистическую значимость различий в среднем чеке между сегментами.
# - Нулевая гипотеза: различий в среднем чеке между группами нет.
# - Альтернативная гипотеза: различия в среднем чеке между группами есть.

# %%
# calculate average cheque and show statistic difference between them
print('P-value составляет:')
print('{0:.3f}'.format(stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], \
                                          orders[orders['group']=='B']['revenue'])[1]))
print('Относительное преимущество группы В перед группой А:')
print('{0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# P-value составляет:
# 0.729
# Относительное преимущество группы В перед группой А:
# 0.259

# %% [markdown]
# Вывод: так как p-value составил 0.729 - выше 0,05 - отвергнуть нулевую гипотезу не можем, статистически значимых различий между средними чеками нет.
#
# Но при этом относительный чек группы В на 25.9% выше чем у группы А, что странно. Возможно, картину исказили выбросы, ведь пока анализ проведен по "сырым" данным.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили значимость различий среднего чека между группами на сырых данных - отлично!

# %% [markdown]
# Самое время "очистить" данные от выбросов и посчитать статистические разницы по данным без выбросов.
# Ранее мы уже определили, что аномально много заказов - это 4 и более, и аномально большие заказы для наших целей - это 30000 и более.
#
# Узнаем, сколько всего пользователей с аномальными данными.

# %%
# show users with abnormally many orders
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > np.percentile(ordersByUsers['orders'],99)]['userId'],
        ordersByUsersB[ordersByUsersB['orders'] > np.percentile(ordersByUsers['orders'],99)]['userId'],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders['revenue'] > np.percentile(orders['revenue'], 95)]['visitorId']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)

print('Количество пользователей с аномальными заказами:')
print(abnormalUsers.shape[0]) 
print('Процент пользователей с аномальными заказами:')
print(abnormalUsers.shape[0] / orders['visitorId'].nunique()*100)
# Out:
# Количество пользователей с аномальными заказами:
# 59
# Процент пользователей с аномальными заказами:
# 5.722599418040737

# %% [markdown]
# 59 пользователя или 5.7% от числа уникальных пользователей. Довольно существенное количество, но из ранее проанализированных персентилей мы сделали вывод что исключение данных по этим пользователям поможет нам избавиться от аномалий без потерь в данных (1-5 персентилей).
#
# Посчитаем статистические разницы без них.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отфильтровали аномалии, посчитали потери пользователей в абсолютном выражении - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Значения границ для фильтрации заданы руками - такой подход делает твоё решение зависимым от внешних данных: при их изменении тебе придётся вносить изменения в код, чтобы текущее решение адекватно работало для других А/В тестов. Очень удобно использовать в качестве значения результат метода для расчёта персентилей.
#
# Например вместо `orders > 2` лучше будет сделать `orders > np.percentile(x, 95)` - такой подход сделает решение более универсальным.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *поправила, спасибо!*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Помимо абсолютных потерь пользователей после фильтрации очень важно также оценить потери и в относительном выражении: любой вид потерь из этих двух сам по себе недостаточно информативен, а вот вместе они уже помогут читателю составить полную картину о масштабе потерь.
#
# Напомню, что относительные потери - это отношение количества аномальных пользователей к общем количеству пользователей из таблицы `orders`. В знаменателе важно учитывать уникальных пользователей, а не количество строк таблицы.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *добавила, спасибо!*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
#create samples with filtered data
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(0, index=np.arange(visitors[visitors['group'] == 'A']['visitors'].sum() - len(ordersByUsersA['orders'])),
            name='orders',),],axis=0,)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(0,index=np.arange(visitors[visitors['group'] == 'B']['visitors'].sum() - len(ordersByUsersB['orders'])),
            name='orders',),],axis=0,) 

print('P-value составляет:')
print('{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Относительное преимущество группы B перед группой А:')
print('{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# P-value составляет:
# 0.018
# Относительное преимущество группы B перед группой А:
# 0.145

# %% [markdown]
# Вывод: По «очищенным» данным также можно отвергнуть нулевую гипотезу - отличия в среднем числе заказов для групп A и B достигли статистической значимости, т.к. p-value равно 0.018 - меньше 0,05.
#
# Относительный выигрыш группы B равен 14.5% — даже выше чем результат в "сырых" данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили значимость различий среднего количества заказов на посетителя между группами на очищеных данных - отлично!

# %% [markdown]
# Теперь посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
# calculate and show difference between filtered average cheques for both groups
print('P-value составляет:')
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)
print('Относительное преимущество группы B перед группой А:')
print(
    "{0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# P-value составляет:
# 0.961
# Относительное преимущество группы B перед группой А:
# -0.014

# %% [markdown]
# Вывод: p-value равен 0.961 - выше 0,05, причем он стал даже больше чем был в "сырых" данных; отвергнуть нулевую гипотезу не можем, статистически значимых различий между средними чеками нет.
#
# А вот относительные данные изменились с точностью до наоборот: после очистки от аномально больших заказов, чеки группы В стали проигрывать чекам группы А, хотя и незначительно - на 1.4%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили значимость различий среднего чека между группами на очищенных данных - отлично!

# %% [markdown]
# ***Вывод по части 2:***
#
# Данные проверены на пропуски, дубликаты и типы, приведены к нужным типам где необходимо;
# Начало и конец периода определены - это 01 августа 2019 и 31 августа 2019, соответственно;
# Выявлены 58 пользователей, которые присутствуют в таблице с заказами и в группе А, и в группе В. Принято решение не удалять этих пользователей из таблицы с заказами, чтобы не исказить данные о конверсии.
#
# По результату А/В теста, можно сделать следующие выводы:
# - графики кумулятивной выручки и кумулятивного среднего чека однозначно показывают преимущество группы В над группой А
# - график относительного изменения кумулятивного среднего количества заказов на посетителя также на стороне группы В - почти весь тестовый период эта группа лидирует
# - по количеству заказов все покупатели распределились довольно равномерно - у большинства 1 заказ, меньше с двумя заказами, значительно реже - с тремя и более. Это подтверждается и статистически: согласно оценке по персентилям, не более 5% покупателей сделали 2 заказа и больше, и менее 1% сделали 4 заказа и больше
# - по выручке выбросов еще меньше - всего два. Средний заказ - около 3000, в то время как выбросы за пределами 28000 (на такую и более сумму покупают не более 5% пользователей нашего интернет-магазина) и 58000 (свыше этой суммы покупали не более 1% пользователей)
#
# Оценка гипотез:
# - по количеству заказов:
#
# по «сырым» данным можно отвергнуть нулевую гипотезу - отличия в среднем числе заказов для групп A и B достигли статистической значимости, т.к. p-value меньше 0,05. Относительный выигрыш группы B равен 13.8%
#
# по «очищенным» данным также можно отвергнуть нулевую гипотезу - отличия в среднем числе заказов для групп A и B достигли статистической значимости, т.к. p-value меньше 0,05. Относительный выигрыш группы B равен 14.5% — даже выше чем результат в "сырых" данных.
# - по среднему чеку:
#
# по "сырым" данным p-value выше 0,05, отвергнуть нулевую гипотезу не можем, статистически значимых различий между средними чеками нет. Но при этом относительный чек группы В на 25.9% выше чем у группы А, что странно.
#
# по "очищенным" данным p-value также выше 0,05, причем он стал даже больше чем был в "сырых" данных; отвергнуть нулевую гипотезу не можем, статистически значимых различий между средними чеками нет. А вот относительные данные изменились с точностью до наоборот: после очистки от аномально больших заказов, чеки группы В стали проигрывать чекам группы А на 1.4%
#
#
# Принято решение по результатам проведенного анализа:
#
# *Остановить тест, зафиксировать преимущество группы В перед группой А.*
#
# В группе В статистически больше заказов, и в относительном выражении число заказов значительно выше, чем в группе А.
# По среднему чеку различий не найдено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Ты принимаешь решение остановить тест и признать отсутствие различий между группами, но далее сама же пишешь про наличие стат значимой разницы между группами по заказам: если хотя бы одна из двух исследуемых метрик демонстрирует наличие стат значимой разницы, то мы уже никак не можем зафиксировать результат с отсутствием различий между группами.
#
# В целом можно демократично написать, что группа В превосходит группу А по заказам, а в среднем чеке различий мы не нашли.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Согласна, очень странное решение приняла. Поправила*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ничего, бывает:)

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
#
# ОБЩИЙ ВЫВОД
#
#
# По результату анализа и приоритизации гипотез с помощью фреймворков ICE и RICE, была выбрана **гипотеза номер 8** с самыми высокими баллами по RICE (112). Высокий балл обоснован максимальным охватом (10 баллов), высоким уровнем влияния на пользователей и большой уверенности в этой оценке, а также небольшими затратами на проверку.
#
# Также сделан вывод о результате А/В теста и принято **решение о прекращении теста**, с победой группы В над группой А - в группе В статистически больше заказов, хотя и нет разницы по среднему чеку.
#
# Данный вывод сделан по "очищенным" от выбросов данным, но надо принять во внимание, что в группу В попали пользователи которые есть и в группе А: 58 пользователей. Удалены они не были, чтобы не искажать расчеты по отношению заказов к визитам (из таблицы с визитами удалить этих пользователей не представляется возможным).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что есть итоговый вывод!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Решение по тесту также нужно будет скорректировать.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Поправила решение, спасибо за замечание!*
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Анастасия, проект получился на довольно хорошем уровне - отличная работа, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с кумулятивными данными выполнена отлично - данные собраны корректно, графики построены верно, выводы сделаны корректные.
#
# В блоке работы с А/В тестом были выбраны верные инструменты, сформулированы и корректно проверены гипотезы, получены правильные выводы - в этом блоке никаких вопросов, молодец!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Анастасия, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
