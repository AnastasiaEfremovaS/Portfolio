# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Согласна работать в диалоге! 🙂
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# #### Открываем файл с данными

# %% [markdown]
# Откроем файл, предварительно импортируя библиотеку Pandas

# %%
#Import pandas library
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Open csv file
df=pd.read_csv('/datasets/real_estate_data.csv')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Все библиотеки лучше импортировать отдельно в первой ячейке. Это позволит тебе в любой момент добавить ещё одну библиотеку без перезаписи переменных.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Ок, разделила! 🙂
# </div>

# %% [markdown]
# #### Оценка содержимого файла

# %% [markdown]
# Оценим общее содержимое файла: посмотрим первые 5 строк

# %%
#Observe first 5 rows of the dataframe
df.head(5)
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# В файле используется тип разделителя '\\', а Pandas.read_csv по умолчанию делит по запятым. Необходимо переписать код, чтобы открыть таблицу в корректном виде, после чего снова выводим 5 первых строк на экран.

# %%
#Open csv file again. Now we use separator type '\'
df=pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
#Set option to display all columns
pd.set_option('display.max_columns', None)
#Observe first 5 rows of the dataframe
df.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Обрати внимание, что часть столбцов заменилась на "...". Чтобы это исправить, нужно увеличить максимальное количество отображающихся столбцов командой
#
# 	pd.set_option('display.max_columns', None)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Классно, не знала этой фишки. Применила выше.
# </div>

# %% [markdown]
# Теперь видно, что файл содержит 22 колонки с информацией. Сразу можно проверить что колонки описаны в удобном "змеином" формате, если какие-то выбиваются - лучше поправить сразу. Так будет удобнее работать над поставленной задачей.

# %%
#All columns are listed
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Все столбцы, кроме одного, соответствуют "змеиному" типу.
#
# Переименуем 'cityCenters_nearest' в 'city_centers_nearest'

# %%
#Rename column into 'snake' format
df=df.rename(columns={'cityCenters_nearest':'city_centers_nearest'})
#All columns are listed
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Теперь оценим общую информацию о данных в таблице

# %%
#Observe common information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# В датафрейме 23699 строк, пропуски есть в данных о высоте полотков (ceiling_height), общем количестве этажей в доме (floors_total), жилой площади (living_area), статусе апартаментов (is_apartment), площади кухни (kitchen_area), наличии балкона или лоджии (balcony), несколько пропусков в данных о местоположении (locality_name), не везде указано количество дней от публикации до снятия (days_exposition) и картографические данные (airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest).

# %% [markdown]
# #### Построение гистограмм для числовых столбцов

# %% [markdown]
# Посмотрим на гистограммы всех числовых столбцов таблицы

# %%
#Show all histograms for numeric data
df.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если после кода вызывающего график добавить ";", то мы избавимся от строчки над графиком)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Применила, так красивее, спасибо )
# </div>

# %% [markdown]
# **Вывод по изучению общей информации:**
#
# - в таблице довольно много пропусков, но некоторые обработать легко - например, отсутствие данных по наличию балкона можно приравнять к отсутствию балкона; если не указано расстояние до ближайшего парка - скорее всего, парка в этой местности просто нет.
# - но есть критичные пропуски, которые могут сильно исказить расчет и понимание рыночной стоимости недвижимости: высота потолка, площадь жилая и кухни. Над этими пропусками точно придется поработать и заполнить их подходящими данными.
# - анализ гистограмм:
# самые интересные и понятные графики получились по картографическим данным, хоть их и немного:
# 1. ближайшие аэропорты, у большинства локаций где они указаны, в 20 км, что похоже на правду;
# 2. ближайшие парки, если они есть, расположены в основном в 500 м от жилья; пруды и прочие водоемы - также. При этом если парк/водоем и есть, то чаще всего один, реже - 2 и совсем роскошь если 3;
# 3. с расстоянием до центра города немного сложнее - пик приходится на 10 км, так что либо отсутствуют данные о недвижимости в центре Санкт-Петербурга, либо в основном в анализ попали дома из спальных районов и пригорода;
# 4. хорошие данные по количеству загруженных фото - очевидно что в среднем загружают около 10 фото, реже когда больше. Более 25 фото - ни разу не загружали;
# 5. Количество комнат также очень показательное - лидирует недвижимость с 2-3 комнатами, в два раза меньше однушек, и совсем редко встречаются квартиры с 4 и более комнатами;
# 6. Общее количество этажей также распределилось логично, хотя этот показатель часто пропущен в данных. Но то что в основном в данных присутствуют квартиры в 1-10-этажных домах выглядит логично
# 7. Данные о последней цене, площади общей, жилой и кухни, высоте потолков трудно интерпретировать, т.к. для них не подходит выбранный по умолчанию масштаб. Для этих показателей неодходимы дополнительные инструменты анализа, т.к. они крайне важны для определения рыночной стоимости недвижимости. Эти инструменты будут применены позже в ходе работы над данным проектом.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Всё верно! Рекомендую создать универсальную функцию, которая будет на вход принимать датафрейм, а на выходе будет выводить все необходимые характеристики поочередно применяя методы head, describe, info, duplicated и т.п.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Хорошо, но уже со следующего проекта, можно? :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Конечно)
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Работа с пропусками

# %% [markdown]
# Ранее уже было перечислено, в каких колонках присутствуют пропуски. Теперь необходимо решить, насколько они критичны и нужно ли заполнить их данными, если да - то какими. Для этого просмотрим поближе пропуски в колонках.
#
# Высота потолков пропущена в 39% записей. Скорее всего, продавец просто не помнит высоту своих потолков и не считает нужным ее указывать. Проставить нули было бы не корректно, и привязать этот показатель к площади квартиры или этажности дома - тоже не разумно. Заполним пропуски медианным значением, но только после того как изучим значения, возможно там присутствуют аномалии.
#
# 1. Общее кол-во этажей пропущено всего в 86 записях (0,2%). Также, местоположение пропущено в 49 записях, это составляет 0,2% от всего массива и ничтожно мало, можно удалить эти строки т.к. на общий вывод они не должны повлиять.
# 2. Показатель "is_apartment" следует расмотреть дополнительно: данных по нему совсем немного. Апартаменты - это вид недвижимости, относительно недавно появившийся на рынке (в начале 2000-х годов). Многие продавцы не понимают, что это такое, и поэтому не заполняют данный пункт никак. Доля апартаментов в общей доле не должна быть большой, поэтому скорее всего пустые данные - это просто не апартаменты.
# 3. Балконы и лоджии - можно предположить, что если данные о балконах не указаны, значит их просто нет. Вряд ли продавец упустит возможность подчеркнуть конкурентное преимущество (наличие балкона) для своей квариры. Заполним пропуски нулями.
# 4. Картографические данные проставляются Яндекс.Картами автоматически и пропущены в том случае, если указанного объекта нет или он далеко. Оставим эти данные без изменений, т.к. если заменить их нулями - информация исказится.
# 5. Также поступим с days_exposition - если данные отсутствуют, значит жилье на момент сохранения данных не было еще продано (есть дата размещения, но нет даты снятия с публикации).
# 5. Жилая площадь и площадь кухни пропущены в 1903 (8%) и 2278 (9,6%) записях, соответственно. Скорее всего, это человеческий фактор: эти данные являются не обязательными к заполнению и продавцы забывают их указать, либо не знают / не помнят точные данные. Но это очень важные для анализа показатели, и их можно привязать к общей площади, которая указана абсолютно по всем данным. Заполним пропуски по этим двум категориям медианным значением имеющихся площадей по группам общих площадей.

# %% [markdown]
# 1. Начнем с удаления строк по ничтожно малым пропускам - общее кол-во этажей и местоположение

# %%
#Eliminate rows with missing data which is immaterial
df=df.dropna(subset=['floors_total'])
df=df.dropna(subset=['locality_name'])

# %% [markdown]
# 2. Далее разберемся с колонкой "is_apartment" - посмотрим, какие и сколько в ней есть уникальные значения

# %%
#Analysis of 'is_apartment' content
df['is_apartment'].value_counts()
# Out:
# False    2710
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Как и предполагали, недвижимость со статусом "апартаменты" встречается редко, всего в 42 случаях. Это как правило объекты, которые ранее были в статусе нежилых (заводы, офисы), но более не нужны по первоначальному назначению и их перестраивают для продажи как жилье.
# Заполним пропуски значением False и проверим, что больше пропусков нет.

# %%
#Use 'fillna' to change NaN to False
df['is_apartment']=df['is_apartment'].fillna(False)
#Check whether column 'is_apartment' doesn't contain any NaN
df['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# 3. Теперь заполним нулями пропуски в показаниях с балконами.

# %%
#Let's replace NaN for balcony to zero 
df['balcony']=df['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Пропуски в столбцах с картографическими данными лучше не трогать. Заполняя их таким образом, ты проставляешь одинаковые расстояния до центра (парка, прудов, аэропорта) для разных квартир, хотя они могут быть расположены в разных частях города. Эти пропуски заполнять не нужно
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Если тут пропуск, то значит квартира не продана. Эти пропуски заполнять не нужно
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Согласна, удалила эти коды
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Обе правки выполнены!
# </div>

# %% [markdown]
# 4. Важные показатели для жилой недвижимости - площадь кухни и жилая площадь - необходимо сперва проанализировать на аномалии. То же самое нужно сделать с общей площадью.
# Если не возникнет необходимости обрабатывать выбивающиеся значения, то пропуски по площади кухни и жилой площади заполним через общую площадь.
#
# Начнем с жилой площади:

# %%
#Observe main data about living area
df['living_area'].describe()
# Out:
# count    21700.000000
# mean        34.454822
# std         22.045359
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Средняя и медиана сходятся во мнении, что чаще всего продают квартиры с жилой площадью около 30 квадратных метров. Максимальная площадь в 410 квадратных метра тоже возможна, если речь идет о большой квартире, таунхаусе или отдельно стоящем доме.
#
# Странные квартиры по 2 квадратных метра жилой площади. Посмотрим на них поближе - выведем на экран все объекты с жилой площадью не более 5 кв.м:

# %%
#Table of items with living area below 5 sqm:
df[df['living_area']<=5]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3242              7   4440000.0        41.0  2017-07-02T00:00:00      1
# 13915            20   6350000.0        52.0  2018-02-06T00:00:00      2
# 17582            11   2680000.0        22.0  2018-08-11T00:00:00      0
# 21758             0   2330000.0        23.0  2018-01-01T00:00:00      0
# 23574            14  64990000.0       139.0  2015-11-24T00:00:00      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 3242              NaN          17.0          3.0     17         False   False
# 13915             3.0           6.0          2.0      2         False   False
# 17582             NaN          25.0          5.0      8         False    True
# 21758             NaN          24.0          2.0     22         False    True
# 23574             3.0           8.0          3.0      8         False   False
#
# ...

# %% [markdown]
# Очень странные объекты, особенно трехкомнатная квартира общей площадью 139 кв.м и с жилой площадью всего 3 кв.м. По 1 кв.м на комнату.
#
# Таких объектов всего 4, удалим их, но сперва нужно заполнить пропуски - чтобы не удалились лишние данные.

# %% [markdown]
# Теперь проведем аналогичный анализ по кухням:

# %%
#Observe main data about kitchen area
df['kitchen_area'].describe()
# Out:
# count    21343.000000
# mean        10.560994
# std          5.900630
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Кухня площадью 112 квадратных метров - это конечно мечта. Но вполне реальная, если общая площадь позволяет. Оценим объекты с кухнями более 100 кв.м:

# %%
#Observe objects with kithen area more than 100 sqm
df[df['kitchen_area']>=100]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 2489              9   12500000.0       255.0  2017-04-21T00:00:00      3
# 5358             20   65000000.0       590.0  2019-02-14T00:00:00     15
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
# 20215             2   85000000.0       249.7  2018-02-01T00:00:00      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 2489              NaN           2.0        153.9      2         False   False
# 5358              3.5           6.0        409.0      3         False   False
# 19540             2.8          25.0        409.7     25         False   False
# 20215             NaN          10.0         72.0      9         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 2489       False         100.7      0.0  Санкт-Петербург           29544.0
# ...

# %% [markdown]
# При общей площади 250-900 кв.м, кухня вполне может быть более 100 метров.
# Теперь оценим разброс по общей площади:

# %%
#Observe main data about total area
df['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Минимум в 12 метров и максимум в 900 метров выглядят адекватно, стандартное отклонение в 35,65 говорит о том что разброс по площади большой. Есть разница между средней и медианой - средняя больше, значит присутствуют "выбросы" в виде нескольких объектов с очень большой площадью.
# Подробный анализ будет произведен в более поздних разделах, а пока можно сделать вывод что данные вполне приемлемые для заполнения пропусков в данных по кухням и жилой площади на основании общей площади.

# %%
# We sort through every unique total area 
for l in df['total_area'].unique():
    # and choose those rows for unique total area where living area is missing 
    # then we fill NaN for living area with mean living area 
    df.loc[(df['total_area'] == l) & (df['living_area'].isna()), 'living_area'] = \
    df.loc[(df['total_area'] == l), 'living_area'].mean()

# Check that all missing items are fulfilled now
print(df['living_area'].isna().sum())
# Out:
# 133

# %%
# We sort through every unique total area 
for k in df['total_area'].unique():
    # and choose those rows for unique total area where kitchen area is missing 
    # then we fill NaN for kitchen area with mean kitchen area 
    df.loc[(df['total_area'] == k) & (df['kitchen_area'].isna()), 'kitchen_area'] = \
    df.loc[(df['total_area'] == k), 'kitchen_area'].mean()

# Check that all missing items are fulfilled now
print(df['kitchen_area'].isna().sum())
# Out:
# 185

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Прекрасный способ для замены! 👏🏻👏🏻👏🏻
# </div>

# %% [markdown]
# Пропуски представлены значениями NaN (not a number), поэтому по ним не рассчиталась средняя для жилой площади и площади кухонь. 133 и 185 значений - это 1,3% от общего количества записей. Удалим эти строки, т.к. на общий вывод такое малое количество не повлияет

# %%
#Let's eliminate objects with 'nan' kitchen area
df=df.dropna(subset=['kitchen_area'])
df=df.dropna(subset=['living_area'])

# %%
#Now we check that there is no missing data in kitchen area
df['kitchen_area'].isna().sum()
# Out:
# 0

# %%
#Now we check that there is no missing data in living area
df['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Теперь можно удалить странные 4 объекта с жилой площадью менее 5 квадратных метров

# %%
#Eliminate objects with living area less 5 sqm
df=df[df['living_area']>5]

# %% [markdown]
# Те пропуски, которые можно было обработать на этом этапе, обработаны.

# %% [markdown]
# #### Обработка типов данных

# %% [markdown]
# Еще раз выведем общую информацию о датафрейме, чтобы увидеть какие типы данных присутствуют в колонках:

# %%
#Observe common information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23285 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23285 non-null  int64
#  1   last_price            23285 non-null  float64
#  2   total_area            23285 non-null  float64
#  3   first_day_exposition  23285 non-null  object
#  4   rooms                 23285 non-null  int64
#  5   ceiling_height        14367 non-null  float64
#  6   floors_total          23285 non-null  float64
#  7   living_area           23285 non-null  float64
#  8   floor                 23285 non-null  int64
#  9   is_apartment          23285 non-null  bool
#  10  studio                23285 non-null  bool
#  11  open_plan             23285 non-null  bool
#  12  kitchen_area          23285 non-null  float64
#  13  balcony               23285 non-null  float64
#  14  locality_name         23285 non-null  object
# ...

# %% [markdown]
# Дата публикации (first_day_exposition) представлена типом данных object, необходимо привести этот показатель к типу datetime.
# Общее количество этажей представлено нецелым числом float64, нужно вернуть этажи к целым числам int64; то же самое с балконами.
# В остальном, данные соответствуют необходимым типам.

# %%
#Change format for 'first_day_exposition' to datetime
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Дата первой публикации приведена к формату datetime и теперь с этими данными можно осуществлять математические операции.

# %%
#Change format of floors and balconies to numeric
df['floors_total']=df['floors_total'].astype('int')
df['balcony']=df['balcony'].astype('int')

# %% [markdown]
# Данные с типом float64 заменим на float32 для экономии памяти.

# %%
#Change format from float64 to float32
df['last_price']=df['last_price'].astype('float32')
df['total_area']=df['total_area'].astype('float32')
df['living_area']=df['living_area'].astype('float32')
df['kitchen_area']=df['kitchen_area'].astype('float32')
df['ceiling_height']=df['ceiling_height'].astype('float32')
df['airports_nearest']=df['airports_nearest'].astype('float32')
df['city_centers_nearest']=df['city_centers_nearest'].astype('float32')
df['parks_around3000']=df['parks_around3000'].astype('float32')
df['parks_nearest']=df['parks_nearest'].astype('float32')
df['ponds_around3000']=df['ponds_around3000'].astype('float32')
df['ponds_nearest']=df['ponds_nearest'].astype('float32')
df['days_exposition']=df['days_exposition'].astype('float32')

# %% [markdown]
# Проверим что в колонках поменялись типы данных

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                     float32
# total_area                     float32
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float32
# floors_total                     int64
# living_area                    float32
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float32
# balcony                          int64
# locality_name                   object
# airports_nearest               float32
# city_centers_nearest           float32
# parks_around3000               float32
# parks_nearest                  float32
# ponds_around3000               float32
# ponds_nearest                  float32
# days_exposition                float32
# dtype: object

# %% [markdown]
# Этажи и балконы теперь представлены целыми числами и не будут смотреться странно при анализе - ведь не бывает полтора балкона или 0,3 этажа.
#
# Все данные приведены к необходимым типам.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Изменение типов данных проведено верно. Можно ещё заменить тип данных с float64 на float32 для экономии памяти.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Готово!
# </div>

# %% [markdown]
# #### Устраняем неявные дубликаты

# %% [markdown]
# Проанализируем названия населенных пунктов на предмет наличия неявных дубликатов. Сразу отсортируем наименования, чтобы удобнее было вести анализ.

# %%
#Observe the list of unique locality names
df['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# Список очень большой, дубликаты присутствуют из-за различного написания слова поселок (через "е" либо через "ё"), из-за того что один населенный пункт написан в разном роде ('посёлок Сапёрное','посёлок Сапёрный'), также иногда населенный пункт указан, а иногда - нет (Кудрово и деревня Кудрово).
#
# Оценим количество уникльных значений до обработки:

# %%
#Observe the number of unique values
df['locality_name'].nunique()
# Out:
# 363

# %% [markdown]
# Для начала, заменим все "ё" на "е" и сразу оценим насколько уменьшилось количество уникальных значений:

# %%
#Replace letter "ё" to "е"
df['locality_name']=df['locality_name'].str.replace('ё','е',regex=True)
#Observe updated number of unique values
df['locality_name'].nunique()
# Out:
# 329

# %% [markdown]
# В связи с тем что для одних населенных пунктов указан атрибут ("деревня", "село" и т.д.), а для других - не указан, лучше удалить атрибуты чтобы не двоить наименования.

# %%
#Replace locality attribution to nothing and change 'Саперное' to 'Саперный'
df['locality_name']=df['locality_name'].str.replace('поселок ','')
df['locality_name']=df['locality_name'].str.replace('городской ','')
df['locality_name']=df['locality_name'].str.replace('коттеджный ','')
df['locality_name']=df['locality_name'].str.replace('деревня ','')
df['locality_name']=df['locality_name'].str.replace('типа ','')
df['locality_name']=df['locality_name'].str.replace('городской ','')
df['locality_name']=df['locality_name'].str.replace('городского ','')
df['locality_name']=df['locality_name'].str.replace('станции ','')
df['locality_name']=df['locality_name'].str.replace('при железнодорожной ','')
df['locality_name']=df['locality_name'].str.replace('садовое товарищество ','')
df['locality_name']=df['locality_name'].str.replace('село ','')
df['locality_name']=df['locality_name'].str.replace('садоводческое некоммерческое товарищество ','')
df['locality_name']=df['locality_name'].str.replace('Саперное','Саперный')
df['locality_name'].nunique()
# Out:
# 303

# %% [markdown]
# Выведем обновленный список и оценим его

# %%
#Observe the updated list of unique locality names
df['locality_name'].sort_values().unique()
# Out:
# array(['Агалатово', 'Александровская', 'Алексеевка', 'Аннино', 'Аро',
#        'Барышево', 'Батово', 'Бегуницы', 'Белогорка', 'Белоостров',
#        'Бокситогорск', 'Большая Вруда', 'Большая Ижора',
#        'Большая Пустомержа', 'Большие Колпаны', 'Большое Рейзино',
#        'Большой Сабск', 'Бор', 'Борисова Грива', 'Бугры', 'Будогощь',
#        'Ваганово', 'Важины', 'Вартемяги', 'Вахнова Кара', 'Вещево',
#        'Виллози', 'Вознесенье', 'Возрождение', 'Войсковицы', 'Войскорово',
#        'Володарское', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Вырица', 'Выскатка', 'Высокоключевой', 'Высоцк', 'Гаврилово',
#        'Гарболово', 'Гатчина', 'Гладкое', 'Глажево', 'Глебычево',
#        'Глинка', 'Гончарово', 'Горбунки', 'Гостилицы', 'Громово',
#        'Дзержинского', 'Дружная Горка', 'Дружноселье', 'Дубровка',
#        'Елизаветино', 'Ефимовский', 'Жилгородок', 'Жилпоселок', 'Житково',
#        'Заводской', 'Заклинье', 'Заневка', 'Запорожское', 'Зеленогорск',
# ...

# %% [markdown]
# Теперь дубликатов нет, каждый населенный пункт встречается по одному разу.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %% [markdown]
# #### Обработка аномальных значений

# %% [markdown]
# Для обработки аномальных значений, еще раз выведем первые 5 строк таблицы, чтобы понять какие строки нужно анализировать.

# %%
#Observe first 5 rows of the dataframe
df.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0  108.000000           2019-03-07      3
# 1             7   3350000.0   40.400002           2018-12-04      1
# 2            10   5196000.0   56.000000           2015-08-20      2
# 3             0  64900000.0  159.000000           2015-07-24      3
# 4             2  10000000.0  100.000000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# 1             NaN            11    18.600000      1         False   False
# 2             NaN             5    34.299999      4         False   False
# 3             NaN            14    80.199997      9         False   False
# 4            3.03            14    32.000000     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Данные по общей, жилой площади и площади кухонь уже были обработаны ранее, но по ним стоит сделать еще проверку: убедимся что жилая площадь вместе с кухней всегда меньше, чем общая площадь. Посмотрим на объекты, где это условие не соблюдается.

# %%
#Check area and show result
df[(df['living_area']+df['kitchen_area'])>df['total_area']]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 184               7   2600000.0   30.200001           2018-02-14      1
# 424              14  11500000.0   98.000000           2016-05-10      3
# 545               9   4700000.0   23.799999           2018-12-28      1
# 551               8   3100000.0   31.590000           2018-03-08      1
# 601              12   5600000.0   53.700001           2017-04-18      2
# ...             ...         ...         ...                  ...    ...
# 22095             6   2194000.0   36.500000           2017-09-27      1
# 22246             6   3100000.0   27.299999           2018-05-29      0
# 22907             9  65000000.0  228.000000           2016-06-02      4
# 23102             0   5800000.0   66.000000           2017-06-09      5
# 23202            13   4919880.0   67.919998           2018-10-23      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Для 126 объектов сумма площадей жилой и кухни превышает общую площадь. Скорее всего, данные вносились не очень аккуратно, либо не были учтены перепланировки в каком-то из показателей.
#
# Чтобы откорректировать данные, заменим общую площадь в этих строках на сумму жилой площади и кухни.

# %%
#Change total area to the sum of iving and kitchen area to correct wrong rows
df['total_area'] = df.where((df['living_area'] + df['kitchen_area']) < df['total_area'], (df['living_area'] + df['kitchen_area']), axis=1)['total_area']

# %%
#Check that wrong rows are gone
df[(df['living_area']+df['kitchen_area'])>df['total_area']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# Проверка пройдена - больше нет общей площади, которая меньше чем сумма жилой площади и кухни.
#
# Оценим общую площадь на "выбросы", редкие значения.

# %%
#Build box plot of total area
df.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Верхняя граница "усов" находится где-то возле 100 кв.метров, это означает что в основном продается недвижимость до 100 кв. м. Свыше 400 кв.м уже явно будут только выбросы. Избавимся от них.

# %%
#Eliminate items with too big total area:
df=df[df['total_area']<400]

# %% [markdown]
# Еще раз оценим выбросы по общей площади.

# %%
#Build box plot of total area updated
df.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Данные в графике распределились равномерно и гармонично.
#
# По остальным данным: нет смысла смотреть данные столбца "is_apartment" - о них также позаботились при обработке пропусков.
# Населенные пункты представляют собой текстовые данные и обработаны в предыдущем разделе.
# По всем остальным данным проведем анализ с применением метода "describe" и других инструментов, при необходимости.

# %% [markdown]
# **Посмотрим на данные о количестве фотографий**

# %%
#Observe main data about total images
df['total_images'].describe()
# Out:
# count    23068.000000
# mean         9.901075
# std          5.675302
# min          0.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         50.000000
# Name: total_images, dtype: float64

# %% [markdown]
# Количество фотографий объекта варьирует от 0 до 50, при этом в среднем их около 10 по одному объекту. Данные выглядят разумно и не подлежат дополнительной обработке

# %% [markdown]
# **Оценим информацию о цене объекта на момент снятия с публикации**

# %%
#Observe main data about last price
df['last_price'].describe().apply(lambda x: '{:.2f}'.format(x))
# Out:
# count        23068.00
# mean       6347298.00
# std        8014154.00
# min          12190.00
# 25%        3450000.00
# 50%        4650000.00
# 75%        6750000.00
# max      330000000.00
# Name: last_price, dtype: object

# %% [markdown]
# Разброс по ценам невероятный - минимальная цена 12 190 руб, максимальная - 763 млн руб
#
# Оценим 5 строк с самыми дешевыми объектами

# %%
#Observe most cheap 5 objects
df.sort_values(by='last_price').head(5)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8793              7     12190.0       109.0           2019-03-20      2
# 17456             7    430000.0        30.4           2019-04-22      1
# 14911             5    430000.0        54.0           2018-06-26      2
# 16274            18    440000.0        40.0           2018-07-10      1
# 5698              7    450000.0        42.0           2017-07-31      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 8793             2.75            25    32.000000     25         False   False
# 17456             NaN             2    16.000000      1         False   False
# 14911             NaN             3    30.859306      3         False   False
# 16274             NaN             5    18.942085      1         False   False
# 5698              NaN             1    23.000000      1         False   False
#
# ...

# %% [markdown]
# Очевидно что объект за 12 190 рублей - это выброс, стоимость 112 рублей за 1 квадратный метр в наше время не реальна. Все последующие объекты стоят уже выше 400 тыс рублей и выглядят адекватно.
# Изавимся от выброса:

# %%
#Eliminate items with inadequate price:
df=df[df['last_price']>12190]

# %% [markdown]
# Теперь оценим самые дорогие 5 объектов:

# %%
#Observe most expensive 5 objects
df.sort_values(by='last_price',ascending=False).head(5)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 1436             19  330000000.0  190.000000           2018-04-04      3
# 22831            18  289238400.0  187.500000           2019-03-19      2
# 16461            17  245000000.0  285.700012           2017-04-10      6
# 8900             13  190870000.0  268.000000           2016-03-25      3
# 19865            20  180000000.0  347.000000           2015-01-21      8
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 1436             3.50             7    95.000000      5         False   False
# 22831            3.37             6    63.700001      6         False   False
# 16461            3.35             7   182.800003      4         False   False
# 8900              NaN             8   132.000000      7         False   False
# 19865            3.90             6   260.000000      3         False   False
#
# ...

# %% [markdown]
# Данные вполне адекватные: в топ попали все квартиры в городе Санкт-Петербург, второй столице России, где недвижимость очень дорогая. Три самых дорогих объекта имеют большой метраж, несколько комнат, огромные кухни и располагаются довольно близко к центру.

# %% [markdown]
# Посмотрим разброс по ценам с помощью графика. Для удобства анализа поделим цену на 1 млн.

# %%
#Build histogram for last price 
fig, ax = plt.subplots()
ax.hist(df['last_price']/1000000, bins = 50, rwidth = 5)
ax.set_title('Цена продажи')
ax.grid()
ax.set_xlabel('Цена в млн.рублей')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Очевидно что цена свыше 50 млн рублей встречается в единицах случаев, избавимся от них.

# %%
#Eliminate items with too high price:
df=df[df['last_price']<50000000]

# %% [markdown]
# Посмтроим график снова.

# %%
#Build histogram for last price 
fig, ax = plt.subplots()
ax.hist(df['last_price']/1000000, bins = 50, rwidth = 5)
ax.set_title('Цена продажи')
ax.grid()
ax.set_xlabel('Цена в млн.рублей')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Данные распределились гармонично, больших выбросов нет.

# %% [markdown]
# **Далее оценим информацию о дате размещения объявлений**

# %%
#Observe the very first exposition date 
df['first_day_exposition'].min()
# Out:
# Timestamp('2014-11-27 00:00:00')

# %%
#Observe the last exposition date 
df['first_day_exposition'].max()
# Out:
# Timestamp('2019-05-03 00:00:00')

# %% [markdown]
# Первое объявление датировано 2014 годом, последнее - 2019. Данные выглядят адекватно.

# %% [markdown]
# **Количество комнат проанализируем с помощью вывода всех возможных вариантов**
#
# Не ожидаем что будет большой разброс - обычно квартиры имеют от 1 до 5 комнат

# %%
df['rooms'].value_counts()
# Out:
# 1     7807
# 2     7790
# 3     5687
# 4     1120
# 5      287
# 0      117
# 6       85
# 7       41
# 8        8
# 9        7
# 10       3
# 11       2
# 14       2
# 16       1
# 19       1
# Name: rooms, dtype: int64

# %% [markdown]
# Как и ожидалось, большинство объектов имеют 1,2,3 или 4 комнаты, реже - 5 и более. Объекты с 10 комнатами также встречаются, но их единицы.
# При этом, есть 117 объектов с 0 комнатами, это явно аномалия и нужно понять почему по этим квартирам не указано ни одной комнаты. Выведем таблицу с этими данными:

# %%
#Create new table to see what are those objects with 0 rooms:
zero_rooms_table = df.query('rooms == 0')
zero_rooms_table.head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 144              1   2450000.0   27.000000           2017-03-30      0
# 349              4   2320000.0   25.000000           2017-09-27      0
# 508              0   3375000.0   34.400002           2017-03-28      0
# 608              2   1850000.0   25.000000           2019-02-20      0
# 716              5   1500000.0   17.000000           2017-06-07      0
# 839             14   1900000.0   35.000000           2017-04-14      0
# 1173            12   3240000.0   29.000000           2018-10-30      0
# 1174             3   3900000.0   32.000000           2016-10-18      0
# 1220             5   3300000.0   27.000000           2017-11-10      0
# 1260             0   2600000.0   27.000000           2018-07-20      0
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 144              NaN            24    15.500000      2         False    True
# ...

# %% [markdown]
# Пока не очевидно, почему комнат указано 0, но по первым 10 объектам можно заключить, что это жилье с небольшой площадью - от 17 до 35 кв.м общей площади. Можно предположить, что это квартиры со свободной планировкой/студии, но для этого необходимо убедиться что все площади таких квартир сравнительно небольшие.

# %%
#Build box plot of all unique squares of flats with zero rooms
zero_rooms_table.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим что медиана находится ниже 30 кв.метров, что подтверждает гипотезу; есть 4 выброса более 50 метров, но это тоже вполне реально что большая квартира продается со свободной планировкой.
# Заполним все объекты с 0 комнатами значением 1, т.к. по факту это квартиры представленные одной большой комнатой / студией.

# %%
#Change zero rooms to 1 room
df.loc[df['rooms'] == 0, 'rooms'] = 1

# %%
#Check updated list of the rooms
df['rooms'].value_counts()
# Out:
# 1     7924
# 2     7790
# 3     5687
# 4     1120
# 5      287
# 6       85
# 7       41
# 8        8
# 9        7
# 10       3
# 11       2
# 14       2
# 16       1
# 19       1
# Name: rooms, dtype: int64

# %% [markdown]
# Проверка показала, что больше нет объектов с 0 комнат.

# %% [markdown]
# Посмотрим на количество во всей базе комнат с помощью графика.

# %%
#Build box plot of room number
df.boxplot(column='rooms')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Недвижимость с более чем 5 комнатами встречается крайне редко, избавимся от таких объектов.

# %%
#Eliminate items with too many rooms:
df=df[df['rooms']<5]

# %% [markdown]
# И снова оценим разброс.

# %%
#Build box plot of room number
df.boxplot(column='rooms')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Данные по комнатам распределились идеально.

# %% [markdown]
# **Анализ высоты потолков**

# %% [markdown]
# Посмотрим все значения, которые принимает показатель "высота потолков"

# %%
#Observe variants of ceiling high
df['ceiling_height'].sort_values()
# Out:
# 22590    1.00
# 5712     1.20
# 16934    1.75
# 20520    2.00
# 19098    2.00
#          ...
# 23687     NaN
# 23690     NaN
# 23692     NaN
# 23695     NaN
# 23696     NaN
# Name: ceiling_height, Length: 22521, dtype: float32

# %% [markdown]
# Высота потолка в 1 и 1,2 метра выглядит не разумно, от них избавимся позже (после заполнения пропусков)

# %%
#Observe updated variants of ceiling high
df['ceiling_height'].sort_values(ascending=False)
# Out:
# 3148     32.0
# 22336    32.0
# 5246     27.0
# 4876     27.0
# 20478    27.0
#          ...
# 23687     NaN
# 23690     NaN
# 23692     NaN
# 23695     NaN
# 23696     NaN
# Name: ceiling_height, Length: 22521, dtype: float32

# %% [markdown]
# Потолки высотой 15 метров еще можно себе представить, скажем в старинном особняке, но более 10 - это явно ошибка. Скорее всего, при указании высоты потолка продавец поставил не там запятую и из-за этого потолок стал в 10 раз выше.
#
# Найдем все значения более 15 метров и поделим на 10.

# %%
#Find all ceiling high more 10 meters and delete by 10
df.loc[df['ceiling_height'] >= 15, 'ceiling_height'] = df.loc[df['ceiling_height'] >= 15, 'ceiling_height'] / 10
#Observe updated variants of ceiling high
df['ceiling_height'].sort_values(ascending=False)
# Out:
# 15061    14.0
# 22309    10.3
# 5863      8.3
# 3474      8.0
# 17442     8.0
#          ...
# 23687     NaN
# 23690     NaN
# 23692     NaN
# 23695     NaN
# 23696     NaN
# Name: ceiling_height, Length: 22521, dtype: float32

# %% [markdown]
# Теперь необходимо заполнить значения по пропускам в высоте потолков. Т.к. данные исправлены и нет выбросов, возьмем для заполнения медиану.

# %%
#Fill missing ceiling high with median high
df['ceiling_height']=df['ceiling_height'].fillna(df['ceiling_height'].median())
#Check that there is no more missing ceiling high
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пришло время избавиться от аномальных потолков в 1 и 1,2 метра.

# %%
#Eliminate ceiling with high less 1.2 m:
df=df[df['ceiling_height']>1.2]

# %% [markdown]
# Убедимся что по показателю "высота потолков" больше нет аномалий.

# %%
#Build box plot of ceiling high updated
df.boxplot(column='ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из общей массы сильно выбиваются значения свыше 8 метров, избавимся от них

# %%
#Eliminate ceiling with high more than 8 m:
df=df[df['ceiling_height']<8]

# %% [markdown]
# Посмотрим на график снова

# %%
#Build box plot of ceiling high updated
df.boxplot(column='ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Существенных выбросов нет, график выглядит гармонично.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен с таким решением, так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %% [markdown]
# **Анализ общего количества этажей в доме**

# %%
#Observe main data about total floors
df['floors_total'].describe()
# Out:
# count    22513.000000
# mean        10.706925
# std          6.578608
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Минимальное количество этажей - 1, максимальное - 60, среднее количество - 10 этажей, медиана - 9. Все это выглядит разумно, нет необходимости далее анализировать этот показатель.

# %% [markdown]
# **Анализ этажа, на котором находится недвижимость**

# %%
#Observe main data about floor of the property
df['floor'].describe()
# Out:
# count    22513.000000
# mean         5.885266
# std          4.869278
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# Данные по этажу на котором находится недвижимость тоже выглядят хорошо: минимальный этаж, на котором находятся продаваемые квартиры - 1, максимальный - 33, в среднем жилье продается на 4-6 этажах.
#
# Проведем небольшой тест - убедимся что этаж, на котором находится продаваемое жилье, всегда меньше чем общее количество этажей в доме.

# %%
#Check that floor of the apartment is less than total floors
(df['floor'] <= df['floors_total']).value_counts()
# Out:
# True    22513
# dtype: int64

# %% [markdown]
# Данные по этажам прошли проверку.

# %% [markdown]
# **Анализ балконов**

# %%
#Observe main data about balconies
df['balcony'].describe()
# Out:
# count    22513.000000
# mean         0.596855
# std          0.959954
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# У большинства объектов нет балконов либо лоджий, судя по тому что медиана равна 0. Другое объяснение - не все указали что в продаваемом объекте есть балкон.
#
# Максимальное количество балконов - 5, что также возможно в очень большой квартире или частном доме.

# %% [markdown]
# **Анализ картографических данных**

# %%
#Observe main data about neareast airports
df['airports_nearest'].describe()
# Out:
# count    17191.000000
# mean     28897.199219
# std      12772.986328
# min          0.000000
# 25%      18428.000000
# 50%      26996.000000
# 75%      37417.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# В среднем недвижимость находится в 29 км от ближайшего аэропорта; максимально удаленный аэропорт - в 85 км, вполне реально т.к. Ленинградская область раскинулась на десятки километров на север, запад и юго-восток от аэропорта Пулково.

# %%
#Observe main data about neareast city centers
df['city_centers_nearest'].describe()
# Out:
# count    17212.000000
# mean     14463.434570
# std       8574.805664
# min        208.000000
# 25%       9734.000000
# 50%      13246.000000
# 75%      16444.500000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Cамый близкий к центру объект находится всего в 208 метрах от центра города. Судя по первому квартилю, четверть объектов находятся ближе 9.7 км от центров, а наиболее удаленные - более чем в 16 км. В среднем объекты находятся в 13-14 км от центра.
#
# Радиусы Санкт-Петербурга от Адмиралтейства (условно центр города) до Сосновой поляны - 20 км, Лахты - 12 км, Девяткино - 17 км, Парнас -19 км, Пр Большевиков - 12 км, Рыбацкое - 18 км. Южная граница Купчино - 14 км. Средняя удаленность от центра в 11 км выглядит разумно.

# %%
#Observe main data about neareast nearest parks
df['parks_nearest'].describe()
# Out:
# count    7517.000000
# mean      493.755219
# std       341.084839
# min         1.000000
# 25%       290.000000
# 50%       458.000000
# 75%       616.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Парки в радиусе 3000 км смотреть нет смысла - их 0, 1, 2 или 3, это было видно еще на этапе анализа гистограмм. Поэтому оценим данные по ближайшим паркам.
# Минимальное расстояние 1 метр - видимо есть объекты которые буквально расположены в парке.
#
# В среднем парки находятся в 450-490 метрах от дома. Максимальное расстояние до парка 3190, что немного больше чем 3000, но выглядит разумно (видимо есть погрешность которую Яндекс допускает).

# %%
#Observe main data about neareast nearest ponds
df['ponds_nearest'].describe()
# Out:
# count    8482.000000
# mean      522.755371
# std       277.639923
# min        13.000000
# 25%       300.000000
# 50%       507.000000
# 75%       733.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# Водоемы в радиусе 3000 км смотреть тоже нет смысла - их 0, 1, 2 или 3, это было видно еще на этапе анализа гистограмм. Поэтому оценим данные по ближайшим водоемам. Самый близкий водоем - в 13 метрах от дома, в это можно поверить т.к. в том же Петербурге многие дома стоят на набережных нескольких рек - Фонтанки, Мойки, Карповки и, конечно, Невы.
#
# В среднем водоемы расположены примерно в 500 метрах от дома. Максимальное расстояние до водоема 1344, что вполне подходит для болотистой и насыщенной прудами и реками Ленинградской области и Санкт-Петербурга.

# %% [markdown]
# **Количество дней размещения объявления от публикации до снятия**

# %%
#Observe main data about exposition days
df['days_exposition'].describe()
# Out:
# count    19534.000000
# mean       179.036499
# std        217.475891
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Минимальное количество дней размещения - 1, в основном объявления висят по 95 дней, исходя из медианы, и 179 день по средней.
#
# На среднюю повлияли слишком долго висящие объявления - максимальное количество 1580 дней, то есть более 4 лет. Т.к. ранее мы установили что первое объявление было размещено в 2014 году, а последнее в 2019 - все сроки в пределах 5 лет нам подходят. Аномалии нет.

# %% [markdown]
# **Вывод по разделу "Предобработка данных"**
#
# 1. Данные проверены на пропуски, дубли и аномальные значения. В результате,
# - в тех квартирах, где пропущена жилая площадь и площадь кухонь, эти данные заполнены средним значением на основании общей площади. Для одинаковой общей площади взяты все показания жилой площади / площади кухни, и пропуски заполнены средним значением по этим показаниям.
# - 1.8% данных удалено из-за пропусков (минимальные данные в общем количестве этажей, местоположении, оставшиеся жилые площади и площади кухонь);
# - пропущенные данные по апартаментам заменены на False, т.к. предполагаем что в случае если квартира не является апартаментами, продавец это не заполнил;
# - пропуски в данных по балконам заменены на ноль, т.к. предполагаем что если не заполнены балконы - значит их нет:
# - по картографическим данным пропуски оставлены без изменений, на расчеты рыночной стоимости объектов они не влияют;
#
# 2. Проверены и боработаны типы данных, в частности данные о дате размещения объявления приведены к формату даты, а данные о количестве этажей и балконов - к целым числам.
#
# 3. Дубликаты в названиях населенных пунктов удалены.
#
# 4. Данные проверены на аномальные значения и выбросы, удалено 4,1% данных, искажающих общую картину (аномальные данные и "выбросы").
# - в 126 объявлений общая площадь меньше чем сумма жилой и кухни. Для таких объектов общая площадь пересчитана как сумма жилой площади и кухни; также удалены сверхбольшие объекты с общей площадью более 400 кв.м.
# - при анализе цен обнаружен объект с аномально низкой ценой - 12190 рублей. Объект удален, а также исключены сверхдорогие объекты стоимостью более 50 млн, их единицы;
# - количество комнат в более 100 объектах было со значением "ноль". Заменено на "один", т.к. предполагаем что это квартиры со свободной планировкой либо квартиры-студии, у большинства которых площадь около 30 кв.м;
# - высота потолков встретилась как аномально маленькая (1-1,2 метра, таких объектов единицы) так и невероятно большая (объекты с потолками свыше 15 метров). Для объектов с потолками более 15 метров применено деление на 10, т.к. предполагаем что продавец не поставил запятую чтобы отделить метры.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>В итоге ты отбросила почти 50% от всех данных, а доступимо отбросить не более 10%. Основные столбцы где стоит поработать с выбросами это стоимость квартиры, высота потолков, количество комнат и общая площадь. Остальные можно не трогать. Если ты всё-таки хочешь обработать все столбцы, то уменьши количество отбрасываемых данных до quantile(0.005) и quantile(0.995). Вне зависимости от того способа, который ты выберешь не забудь проверить количество отбрасываемых данных. С этим поможет следующая команда
#
# 	new_data.shape[0] / old_data.shape[0]
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Поправила все, узнала в чем была проблема. Оказывается нужно сперва заполнить пропуски, и только потом удалять аномальные значения. Не знала об этом.
#     Стоимость квартиры, высота потолков, количество комнат и общая площадь проработаны:
#     1. удалена аномально низкая стоимость квартиры
#     2. потолки все в пределах 1-20 метров сейчас
#     3. кол-во комнат: 0 заменены на 1
#     4. общая площадь прошла проверку на адекватность - сумма жилой площади и кухни сейчас не превышает общую
#
#     Везде проверяю теперь данные через shape, чтобы не удалить лишнего ...
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v2:</b>
# <br>Аномалии остались. Давай разберём на примере общей площади (график ниже). На графике чётко видно, что после 200м квартир практически нет, а после 300 линии даже не видно. В данном случае аномальными значениями можно считать все квартиры больше 200-300м. Значит эти значения нужно отбросить.
# </div>

# %%
#код ревьюера
df['total_area'].hist(bins=30);

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Удалила все аномалии, в основном на основании данных box plot, по цене смотрела на гистограмме.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Отлично! Теперь всё верно)
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавляем столбец "sqm_price", в котором будет указана цена за 1 квадратный метр

# %%
#Add new column as division of price and total area
df['sqm_price'] = df['last_price'] / df['total_area']

# %% [markdown]
# Добавим столбцы с днем недели, месяцем и годом публикации объявления - "exposition_week_day", "exposition_month", "exposition_year"

# %%
#Add new columns as processing of first day exposition
df['exposition_week_day'] = df['first_day_exposition'].dt.weekday
df['exposition_month'] = df['first_day_exposition'].dt.month
df['exposition_year'] = df['first_day_exposition'].dt.year

# %% [markdown]
# Еще один новый столбец - тип этажа, на котором находится квартира - "floor_type"

# %%
#Function to find type of the floor - 1st, last and other
def categorize_floor(floor, floors_total):
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    else:
        return 'другой'
#And add this type to new column 'floor_type'
df['floor_type'] = df.apply(lambda x: categorize_floor(x['floor'], x['floors_total']), axis=1)

# %% [markdown]
# Добавляем столбец с расстоянием до центра города в км - "city_centers_km"

# %%
#Find distance to center in km
df['city_centers_km'] = df['city_centers_nearest'] / 1000
#Round distance to integer
df['city_centers_km'] = round(df['city_centers_km'], 0)

# %% [markdown]
# Проверим что новые столбцы появились в таблице

# %%
#Observe all columns of dataframe
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition', 'sqm_price', 'exposition_week_day',
#        'exposition_month', 'exposition_year', 'floor_type', 'city_centers_km'],
#       dtype='object')

# %% [markdown]
# **Вывод по разделу Добавление новых столбцов**
#
# Для дальнейшего анализа, в таблицу с данными добавлены столбцы:
# - цена за 1 квадратный метр (sqm_price)
# - столбцы с днем недели, месяцем и годом публикации объявления (exposition_week_day, exposition_month, exposition_year)
# - тип этажа, на котором находится квартира - первый, последний или другой (floor_type)
# - столбец с расстоянием до центра города в км (city_centers_km)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# ####  Оценка данных при помощи гистограмм

# %% [markdown]
# *Анализ общей площади*

# %%
#Histogram for total area 
fig, ax = plt.subplots()
ax.hist(df['total_area'], bins = 50, rwidth = 5)
ax.set_title('Площадь общая')
ax.grid()
ax.set_xlabel('Площадь в кв.метрах')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Полученный график можно интерпретировать так: подавляющее большинство недвижимости, продаваемое в 2014-2019 гг по предоставленным данным, было в пределах общей площади в 100 кв.м. Наибольшее количество - квартиры площадью 30-50 кв.м.
#
# Пик гистограммы приходится на отметку в 40, то есть лидеры продаж - квартиры площадью 40 кв.метров.

# %% [markdown]
# *Анализ жилой площади*

# %%
#Histogram for living area 
fig, ax = plt.subplots()
ax.hist(df['living_area'], bins = 50, range=(0,300), rwidth = 5)
ax.set_title('Площадь жилая')
ax.grid()
ax.set_xlabel('Площадь в кв.метрах')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# По аналогии с общей площадью, мы отсеяли 5 объектов с жилой площадью свыше 300 кв.м.
# На графике очень хорошо видно, что наиболее продаваемые объекты - "пики" гистограммы - это недвижимость с жилой площадью 20-30 кв.м

# %% [markdown]
# *Анализ площади кухонь*

# %%
#Histogram for kitchen area 
fig, ax = plt.subplots()
ax.hist(df['kitchen_area'], bins = 50, range=(0,112), rwidth = 5)
ax.set_title('Площадь кухни')
ax.grid()
ax.set_xlabel('Площадь в кв.метрах')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Ранее мы анализировали площади кухонь и видели что есть несколько объектов с площадью кухни около 100 кв.м, но их считанные единицы: гистограмма дает понять, что подавляющее большинство объектов имеют кухни площадью около 10 кв.м. Пик гистограммы приходится именно на такую площадь.

# %% [markdown]
# *Анализ цены продажи*

# %%
#Histogram for last price 
fig, ax = plt.subplots()
ax.hist(df['last_price']/1000000, bins = 50, range=(0,50), rwidth = 5)
ax.set_title('Цена продажи')
ax.grid()
ax.set_xlabel('Цена в млн.рублей')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут можно разделить все значения в столбце last_price на 1 млн, чтобы они пришли в более понятный вид)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Применила, стало понятнее :)
# </div>

# %% [markdown]
# Можно сделать вывод, что на рынке преобладают объекты с ценой до 10 млн. руб; пик продаж приходится на жилье с ценой около 5 млн. рублей.
#
# В небольшом количестве присутствуют объекты стоимостью 10-20 млн.рублей, свыше 20 млн.рублей уже единицы.

# %% [markdown]
# *Анализ количества комнат*

# %%
#Histogram for rooms number
fig, ax = plt.subplots()
ax.hist(df['rooms'], bins = 25, rwidth = 5)
ax.set_title('Количество комнат')
ax.grid()
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Вполне ожидаемо пики гистограммы приходятся на однокомнатные и двухкомнатные квартиры, чуть меньше трехкомнатных и значительно меньше - четырехкомнатных.

# %% [markdown]
# *Анализ высоты потолков*

# %%
#Histogram for ceiling high
fig, ax = plt.subplots()
ax.hist(df['ceiling_height'], bins = 10, rwidth = 5)
ax.set_title('Высота потолка')
ax.grid()
ax.set_xlabel('Высота в метрах')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v2:</b>
# <br>Код падает с ошибкой. Поправь, пожалуйста
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправила, прошу прощения! Умудрилась медиану по потолкам вставить не значением, а словом (тут эмодзи обезьянки, закрывающей глаза))
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Бывает) Спасибо, что поправила)
# </div>

# %% [markdown]
# Пики гистограммы приходятся на 2,5-3 мера, что соответствует реальности: в основном потолки в панельных домах составляют 2,4 метра, в новых домах этот показатель чуть выше, но обычно тоже в пределах 3 м. Квартиры в старом фонде в Санкт-Петербурге обычно имеют потолки 3-3,5 метра.
# Потолки выше 4 метров встречаются очень редко, это скорее всего особняки или переделанные для продажи промышленные здания.

# %% [markdown]
# *Анализ этажа квартиры*

# %%
#Histogram for the floor
fig, ax = plt.subplots()
ax.hist(df['floor'], bins = 30, rwidth = 5)
ax.set_title('Этаж квартиры')
ax.grid()
ax.set_xlabel('Кол-во этажей')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Ранее в анализе мы уже отметили что этажи продаваемых объектов варьируют от 1 до 30; на гистограмме это подтверждается, кроме того виден общий тренд: наиболее продаваемые квартиры находятся на 1-6 этажах. Реже в два раза продаются квартиры на 5-10 этажах, и далее с возрастанием этажа падает количество проданных квартир. Выше 25 этажа продажи единичны, во многом из-за того что высоток по 30-40 этажей еще пока не так много на рынке недвижимости.
#
# Абсолютные лидеры - объекты с 1 или 2 комнатами, при этом в 1-комнатные включены квартиры-студии и объекты со свободной планировкой.

# %% [markdown]
# *Анализ типа этажа квартиры*

# %%
#Histogram for the floor type
fig, ax = plt.subplots()
ax.hist(df['floor_type'], bins = 30, rwidth = 5)
ax.set_title('Тип этажа')
ax.grid()
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Первый и последний этажи продаются неплохо, но прочие - в пять раз чаще.

# %% [markdown]
# *Анализ общего количества этажей*

# %%
#Histogram for total floors
fig, ax = plt.subplots()
ax.hist(df['floors_total'], bins = 40, rwidth = 5)
ax.set_title('Этажи')
ax.grid()
ax.set_xlabel('Кол-во этажей')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Есть в продаже и 60-этажные дома, но в абсолютном большинстве классические пяти- и девятиэтажки, а также пики гистограммы выделили 12,14 и 16-этажные дома.

# %% [markdown]
# *Анализ расстояния до центра города в метрах*

# %%
#Histogram for distance to city center
fig, ax = plt.subplots()
ax.hist(df['city_centers_nearest'], bins = 30, rwidth = 5)
ax.set_title('Расстояние до центра города')
ax.grid()
ax.set_xlabel('Метры')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Для тех объектов, где расстояние было указано, можно с уверенностью сказать что лидируют объекты находящиеся в 11-17 км от центра. Ранее мы уже приводили примерные радиусы Санкт-Петербурга - расстояния от Адмиралтейства до спальных и наиболее густонаселенных районов. Гистограмма выглядит вполне адекватно проведенному ранее анализу.

# %% [markdown]
# *Анализ расстояния до ближайшего аэропорта*

# %%
#Histogram for distance to airport
fig, ax = plt.subplots()
ax.hist(df['airports_nearest'], bins = 30, rwidth = 5)
ax.set_title('Расстояние до ближайшего аэропорта')
ax.grid()
ax.set_xlabel('Метры')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Для большинства объектов расстояние до аэропорта (скорее всего имеется ввиду Пулково) составляет в среднем от 10 до 40 км, что вполне реально для размашистой карты Санкт-Петербурга и области.

# %% [markdown]
# *Анализ расстояния до ближайшего парка*

# %%
#Histogram for distance to nearest park
fig, ax = plt.subplots()
ax.hist(df['parks_nearest'], bins = 30, range=(0,1000), rwidth = 5)
ax.set_title('Расстояние до ближайшего парка')
ax.grid()
ax.set_xlabel('Метры')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Мы ограничили анализ расстоянием в 1500 м, т.к. уже более чем за 800 м парки встречаются очень редко. Там где парки присутствуют, чаще всего они встречаются в пределах 150-700 метров от объекта недвижимости.

# %% [markdown]
# *Анализ дня и месяца публикации объявления*

# %%
#Histogram for the first day of exposition
fig, ax = plt.subplots()
ax.hist(df['first_day_exposition'], bins = 50, rwidth = 5)
ax.set_title('Анализ дня публикации объявления')
ax.grid()
ax.set_xlabel('Дата')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Виден довольно четкий тренд на рост количества объявлений с 2015 до 2019 года. "Провал" в 2017 году связан, скорее всего, с финансовым кризисом и отсутствием возможности для покупателей взять ипотеку.
#
# Оценим также активность размещения объявлений в зависимости от дня недели и месяца

# %%
#Histogram for the week day of exposition
fig, ax = plt.subplots()
ax.hist(df['exposition_week_day'], bins = 50, rwidth = 5)
ax.set_title('День недели размещения объявления')
ax.grid()
ax.set_xlabel('День недели')
ax.set_ylabel('Кол-во продаж')
plt.show()

# %% [markdown]
# Гистограмма наглядно демонстрирует, что по будним дням объявления размещают чаще, чем в выходные. Возможно это связано с тем, что размещают объявления не только частные лица, но и риэлторские фирмы, которые не работают в выходные.

# %%
#Histogram for the month of exposition
fig, ax = plt.subplots()
ax.hist(df['exposition_month'], bins = 50, rwidth = 5)
ax.set_title('Месяц размещения объявления')
ax.grid()
ax.set_xlabel('Месяц года')
ax.set_ylabel('Кол-во продаж')
plt.show()

# %% [markdown]
# Тренды по месяцам довольно очевидные и понятные - в январе, мае и декабре много праздничных дней, поэтому в эти месяцы провал в активности. Февраль, март, апрель лидируют по активности; летом активность чуть ниже, люди многие в отпусках и не занимаются недвижимостью. Осенью рынок недвижимости оживает и активность растет в августе, сентябре, октябре и ноябре.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для того чтобы подписать график мы можем использовать метод plt.title() и в конце кода применить plt.show(). По ссылкам ниже можно почитать подробнее как добавить название для графика или подписать его оси
#
#     https://pyprog.pro/mpl/mpl_title.html
#     https://pyprog.pro/mpl/mpl_axis_signatures.html
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо большое, так гораздо приятнее "читать" графики!
# </div>

# %% [markdown]
# #### Анализ дней размещения объявления

# %% [markdown]
# *Построим гистограмму по дням размещения объявления*

# %%
#Histogram for the days of exposition
fig, ax = plt.subplots()
ax.hist(df['days_exposition'], bins = 50, rwidth = 5)
ax.set_title('Кол-во дней размещения объявления')
ax.grid()
ax.set_xlabel('Кол-во дней')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Пики графика приходятся на первую сотню дней. Рассмотрим ее подробнее

# %%
#Histogram for the first 100 days of exposition
fig, ax = plt.subplots()
ax.hist(df['days_exposition'], bins = 50, range=(0,100), rwidth = 5)
ax.set_title('Кол-во дней размещения объявления')
ax.grid()
ax.set_xlabel('Кол-во дней')
ax.set_ylabel('Кол-во объявлений')
plt.show()

# %% [markdown]
# Два пика - примерно на 45 и 60 днях. Это связано с особенностью работы сервиса Яндекс.Недвижимость: разместить объявление о продаже можно на 45 дней для объектов стоимостью до 4,5 млн.руб, на 60 дней - для объектов стоимостью до 4,5 млн — 45 дней и на 90 дней для более дорогих объектов.

# %% [markdown]
# *Посчитаем среднее и медиану по дням размещения объявления*

# %%
#Main information about exposition days number
df['days_exposition'].describe()
# Out:
# count    19534.000000
# mean       179.036499
# std        217.475891
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее значение по дням размещения объявления составило около 160 дней, а медиана - 74 дня.
# Это говорит о том, что есть несколько значений с очень большим количеством - один объект продавался более 4 лет (1580 дней) и "сдвинул" значение средней вправо.
# Медианное значение в 74 дня говорит о том, что в основном квартиры продаются за 2,5 месяца. Это вполне согласуется с выводами под гистограммой.

# %% [markdown]
# *Общий вывод по дням размещения объявления*

# %% [markdown]
# Быстрой продажей можно считать реализацию жилья в течение 50 дней. Сверхбыстрые продажи - до 25 дней.
#
# Если же объект не продан в течение 3 месяцев, то это уже можно начать относить к медленным продажам. Также можно выделить неликвиды - это объекты которые не продаются свыше 600 дней.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен! Если интересно, то можно посмотреть на диапазон от 0 до 100 дней. Там есть пики, которым можно найти очень логичное объяснение</div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Вижу два пика на 45 и 60 дне примерно, но почему-не могу объяснить... Предположила что в эти дни цена снижается как-то автоматически, либо объявления закрывает система, но это не точно ))
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Это особенность функционирования системы размещения объявлений) Убедиться в этом можно по ссылке ниже
#
# 	https://yandex.ru/support/realty/owner/home/add-ads-housing.html
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Эх, а я ведь гуглила.. но этой информации не нашла. И еще никогда не размещала сама объявления - только смотрела для покупки/аренды себе
# </div>

# %% [markdown]
# #### Анализ факторов влияющих на стоимость объекта

# %% [markdown]
# Для начала оценим как зависит *цена объекта от общей площади*

# %%
#Build scattering diagram for total area and last price
df.plot(x='total_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# Диаграмма рассеяния показывает плотную зависимость цены от общей площади для объектов до 100 кв.м, но уже для объектов около 200 кв.м встречаются квартиры с ценой в два раза больше чем у основной массы.
# Для объектов площадью 250 кв.м выбросы еще больше - тут можно встретить недвижимость со средней ценой и с очень высокой тоже.

# %% [markdown]
# *Зависимость цены от жилой площади* оценим таким же образом

# %%
#Build scattering diagram for living area and last price
df.plot(x='living_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='living_area', ylabel='last_price'>

# %% [markdown]
# Картина получается очень похожая на предыдущую, что не удивительно, ведь жилая площадь как правило напрямую зависит от общей. Плотная зависимость наблюдается для площадей до 50 кв.м, далее начинается рассеивание и уже для площадей 60-100 кв.м попадаются выбросы - квартиры с большей стоимостью чем большинство. Для площадей 100-175 кв.м зависимости практически нет.

# %% [markdown]
# Посмотрим как зависит *цена от площади кухни*

# %%
#Build scattering diagram for kitchen area and last price
df.plot(x='kitchen_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>

# %% [markdown]
# Аналогично общей и жилой площади, кухня напрямую коррелирует с ценой только для самых небольших объектов. Начиная уже с 10 кв.м встречаются кухни, в которых объекты стоят больше чем в большинстве.
# Интересная тенденция для кухонь в 40 кв.м - отчетливо видно "столбик" из нескольких объектов, то есть эти квариры с одинаковой площадью кухонь были проданы за разные деньги. Видимо, цена для некоторых была выше из-за жилой площади, местоположения объекта, наличия балконов или из-за других факторов.
#
# Свыше 50 кв.м зависимость пропадает.

# %% [markdown]
# *Зависимость цены от количества комнат*

# %%
#Build scattering diagram for rooms number and last price
df.plot(x='rooms', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# Логично, что чем больше комнат, тем обычно выше цена. Но данная диаграмма показывает, что бывают квариры недорогие с 4 комнатами и наоборот - встречаются дорогие однушки.
#
# Все потому, что кроме количества комнат очень важна их площадь. Среди однокомнатных есть объекты большого метража со свободной планировкой, и среди 2-4 комнатных - очень маленькие по площади объекты.

# %% [markdown]
# *Анализ типа этажа - первый, последний, другой*

# %%
#Find median price for each type of the floor
price_floor_type = df.pivot_table(index='floor_type',values='last_price',aggfunc='median')
price_floor_type
# Out:
#             last_price
# floor_type
# другой       4800000.0
# первый       3890000.0
# последний    4200000.0

# %%
#Build bar plot to visualize median price for each floor type
price_floor_type.plot(y='last_price',kind='bar')
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# Судя по медианной цене, больше всего приходится делать скидку за первый этаж. Это логично - многим не нравится что под ними подвал (холодно, сыро, мыши); также не любят покупатели и последний этаж (протечки, перебои с водоснабжением / обогревом).
#
# А вот за средние этажи можно требовать рыночную цену.

# %% [markdown]
# *Зависимость цены от недели, месяца и года размещения* показана на графиках ниже

# %%
#Find median price for each week day
price_week_day = df.pivot_table(index='exposition_week_day',values='last_price',aggfunc='median')
#Build bar plot for median price per week day
price_week_day.plot(y='last_price',kind='bar')
# Out:
# <AxesSubplot:xlabel='exposition_week_day'>

# %% [markdown]
# Цена по дням недели распределилась равномерно, можно отметить лишь незначительное повышение цены по вторникам

# %%
#Find median price for each month
price_month = df.pivot_table(index='exposition_month',values='last_price',aggfunc='median')
#Build bar plot for median price per month
price_month.plot(y='last_price',kind='bar')
# Out:
# <AxesSubplot:xlabel='exposition_month'>

# %% [markdown]
# В апреле, сентябре, ноябре и декабре цена выше, чем в остальные месяцы.

# %%
#Find median price for each year
price_year = df.pivot_table(index='exposition_year',values='last_price',aggfunc='median')
#Build bar plot for median price per year
price_year.plot(y='last_price',kind='bar')
# Out:
# <AxesSubplot:xlabel='exposition_year'>

# %% [markdown]
# С 2014 до 2017 года цена падала, т.к. падал курс доллара, а недвижимость оценивается в привязке к курсу доллара. Но после этого начался рост курса и последующий финансовый кризис, чем обосновывается рост цены начиная с 2018 года.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тут необходимо рассчитать по отдельности зависимость для дня недели, месяца и года. Мы ведь для этого создавали отдельные столбцы
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправила, теперь три графика и выводы по ним
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v2:</b>
# <br>Для категории дня недели, месяца и года продажи нужно построить barplot или гистограмму рассчитав среднее значение или медиану (ты так сделала для категории этажа). После этого необходимо написать о зависимости цены от этих параметров
#
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправилась
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# #### Анализ средней цены наиболее популярных населенных пунктов

# %% [markdown]
# Найдем 10 населенных пунктов с наибольшим числом объявлений

# %%
#Group all objects by localities and find mean price per sqm 
popular_localities = df.groupby('locality_name')['sqm_price'].agg(['count', 'mean'])
#Sort most popular localities in descending order
most_popular_localities = popular_localities.sort_values(by='count',ascending=False)
#Leave only 10 localities
ten_most_popular_localities=most_popular_localities[:10]
ten_most_popular_localities
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  14824  111929.421875
# Мурино             526   85426.382812
# Кудрово            443   95102.539062
# Шушары             435   78421.164062
# Всеволожск         389   68611.632812
# Пушкин             360  103052.703125
# Колпино            333   75460.921875
# Парголово          325   90291.781250
# Гатчина            302   68676.976562
# Выборг             233   58372.085938

# %% [markdown]
# Абсолютный лидер по количеству объявлений - конечно же город Санкт-Петербург, тут нежвижимости продается на два порядка больше чем в остальных населенных пунктах.
#
# Меньше всего объявлений в топ-10 населенных пунктов - в Выборге.
#
# Теперь отсортируем таблицу по цене, чтобы увидеть в каких населенных пунктах из топ-10 самые высокие и самые низкие цены на недвижимость.

# %%
#Show localities sorted by price 
ten_most_popular_localities.sort_values(by='mean',ascending=False)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  14824  111929.421875
# Пушкин             360  103052.703125
# Кудрово            443   95102.539062
# Парголово          325   90291.781250
# Мурино             526   85426.382812
# Шушары             435   78421.164062
# Колпино            333   75460.921875
# Гатчина            302   68676.976562
# Всеволожск         389   68611.632812
# Выборг             233   58372.085938

# %% [markdown]
# Так совпало, что самая высокая цена за 1 кв.метр в самом популярном городе - Санкт-Петербурге, и составляет 112 тыс. рублей за кв.м; и самая низкая цена - в наименее популярном Выборге из топ-10 - составила 58 тыс.рублей, что почти в два раза ниже питерской.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тут нужно выделить населённые пункты с максимальной и минимальной ценой из того списка топ10 что ты выводишь выше
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Ясно. Неправильно поняла задание, оно неоднозначно звучит. Поправила
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# #### Расчет средней цены километра до центра города

# %% [markdown]
# Выделим из таблицы данные только по городу Санкт-Петербург

# %%
#Create new table with Saint Peterburg only
spb_property = df.query('locality_name=="Санкт-Петербург"')
#Observe first 5 rows of new table
spb_property.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0  108.000000           2019-03-07      3
# 2            10   5196000.0   56.000000           2015-08-20      2
# 4             2  10000000.0  100.000000           2018-06-19      2
# 7             5   7915000.0   71.599998           2019-04-18      2
# 9            18   5400000.0   61.000000           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# 2            2.65             5    34.299999      4         False   False
# 4            3.03            14    32.000000     13         False   False
# 7            2.65            24    42.771427     22         False   False
# 9            2.50             9    43.599998      7         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Найдем среднюю цену для каждого километра до центра города

# %%
#Create new table with mean sqm price for each km to center
spb_km_price = spb_property.groupby('city_centers_km')['sqm_price'].agg(['mean'])
#Show new table first 5 rows
spb_km_price.head(5)
# Out:
#                           mean
# city_centers_km
# 0.0              172723.890625
# 1.0              148101.171875
# 2.0              141415.140625
# 3.0              121048.031250
# 4.0              128486.890625

# %%
#Show new table last 5 rows
spb_km_price.tail(5)
# Out:
#                           mean
# city_centers_km
# 25.0              91909.773438
# 26.0              86383.281250
# 27.0             132115.718750
# 28.0              81161.914062
# 29.0              72953.367188

# %% [markdown]
# Полученные данные адекватны.
#
# Для большего понимания зависимости средней цены от километра, построим диаграмму.

# %%
#Build line plot for each km with sqm price
spb_km_price.plot(y='mean',kind='bar',grid=True,figsize=(13,5))
# Out:
# <AxesSubplot:xlabel='city_centers_km'>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>В данных остался не только Питер
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо, поправила данные
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# На графике четко виден общий тренд - чем дальше от центра, тем ниже средняя цена недвижимости за кваратный метр. Есть пик на 27 км, но вполне возможно что это недвижимость премиум класса.
#
# Самая высокая стоимость километра - в самом центре, в пределах 1 км. и составляет почти 175000 рублей за кв.метр.
#
# Но это средняя цена за 1 кв.м в этом районе, а сколько же стоит сам километр?
#
# Для целей понимания того, на сколько недвижимость может быть дороже в зависимости от удаления от центра города, рассчитаем цену километра так: найдем разницу между самым дорогим и самым дешевым километром и поделим на количество км. Это довольно условная цена километра, но для примерного понимания подойдет.

# %%
#Count and show price of one km in Saint-Petersburg
spb_one_km_price = (spb_km_price['mean'].max()-spb_km_price['mean'].min())/29
spb_one_km_price
# Out:
# 3440.3628771551726

# %% [markdown]
# Получилась цифра в 3440 рублей, которую можно использовать для оценки стоимости недвижимости за кв.м при изменении количества километров от центра. Например, если мы сравниваем жильё в 5 км от центра и в 10 км, то условно разница за квадратный метр для сопоставимой по классу недвижимости будет 17200 руб (3440*(10-5км))

# %% [markdown]
# ***Вывод по разделу Исследовательский анализ данных***

# %% [markdown]
# 1. Изучены основные параметры объектов, благодаря чему можно сделать выводы о наиболее популярных из них:
# - чаще всего продаются объекты общей площадью 50-100 кв.м, жилой площадью 20-30 кв.м и с площадью кухни около 10 кв.м;
# - подавляющее большинство объектов продаются за 5-10 млн.рублей, но есть и исключения, выше 50 млн. продаются единицы;
# - большинство проданных объектов имеют 1 или 2 комнаты, реже 3-4;
# - средняя высота потолка продаваемых объектов составляет 2,5-3 метра;
# - наибольшая масса продаж приходится на 1-6 этажи, в два раза реже - 7-10 этажи, единицы на этажи выше. Дома, в которых продаются объекты - это в основном 5,9-этажки, реже 12,14,16-этажки. Значительно меньше продаж в домах с прочей этажностью;
# - расстояние до центра города составляет в среднем 11-17 км, до блиайшего аэропорта 10-50 км, если рядом и есть парк, то он в пешей доступности 150-700 метров;
# - количество размещенных объявлений росло с течением времени и достигало пиков в 2018 и 2019 гг; чаще всего объявления о продаже размещают в будни и в "рабочие" месяцы - в апреле и в августе-ноябре.
# 2. Проведен анализ количества дней размещения объявлений, из которого можно сделать вывод что быстрой продажей считается реализация в течение 50 дней, сверхбыстрой продажей - до 25 дней; медленные продажи - более 3 месяцев, неликвиды - это объекты которые не продаются свыше 600 дней.
# 3. Изучены факторы влияющие на стоимость объекта, вывод можно сделать следующий:
# - цена напрямую зависит от общей, жилой площади и площади кухни только для небольших и недорогих объектов. Чем крупнее объект, тем больше разброс;
# - количество комнат не так сильно влияет на стоимость, как их площадь: встречаются дорогие обхекты с 1 комнатой и дешевые с 4 комнатами;
# - цена за первый и последний этажи немного ниже, чем за прочие;
# - от даты размещения цена напрямую не зависит.
# 4. Анализ средней цены наиболее популярных населенных пунктов показал, что топ-10 включает Санкт-Перебург (абсолютный лидер), Мурино, Кудрово, Шушары, Колбино, Всеволожск, Пушкин, Колпино, Парголово, Гатчину и Выборг. В основном это города-спутники Санкт-Петербурга.
# - самая низкая цена за 1 кв.м в Выборге
# - самая высокая цена - в Санкт-Петербурге
# 5. Для Санкт-Петербурга также произведен расчет средней цены 1 кв.м недвижимости в зависимости от расстояния до центра города, который показывает четкую обратную зависимость цены и количества километров от центра. Самое дорогое жилье находится в пределах 8 км от центра и на 27 км, общий тренд - снижение цены с удалением от центра.
#
# Рассчитана условная стоимость 1 километра - 3440 рублей - это примерный показатель того, на сколько растет стоимость 1 кв.м жилья при приближении к центру города.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
#
# Обработана база данных сервиса Яндекс.Недвижимость с архивом объявлений о продаже квартир в Санкт-Петербурге и Ленинградской области за 2014-2019 гг.
#
# Произведен анализ данных на наличие пропусков и дубликатов, в результате все пропуски заполнены либо удалены (1.2% от всех данных), дубликаты устранены.
#
# Изучены аномалии и выбросы в данных с применением гистограмм и диаграммы размаха, критичные данные обработаны: единичные случаи удалены (4.1%), ошибочные данные заменены на корректные.
#
# Исследованы различные параметры данных, которые могут влиять на цену недвижимости. Подтверждена разумность данных, таких как площадь объектов, количество комнат, этаж объекта и общее кол-во этажей, высота потолков, расстояние до центра города, аэропорта и парков.
#
# Произведен анализ факторов, влияющих на стоимость объекта, а также выделены самые популярные объекты с наибольшим количеством объявлений и посчитана условная стоимость 1 км для Санкт-Петербурга. Эта стоимость показывает на сколько растет стоимость 1 кв.м жилья при приближении на 1 км к центру города.
#
# Общий вывод: после обработки, данные корректны и могут быть использованы для анализа рыночной стоимости недвижимости, а также для построения автоматизированной системы.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>После всех внесённых правок, обязательно перепроверь общий вывод и промежуточные выводы и поправь их по необходимости
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Все исправлено
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Ты хорошо потрудилась, большая часть работы сделана, но остаётся внести следующие правки:
# <br>- не заполнять пропуски в столбцах с картографическими данными
# <br>- не заполнять пропуски в столбце days_exposition
# <br>- поправить границы для аномальных значений (высота потолка, площадь квартиры, стоимость, количество комнат)
# <br>- изучить зависимость цены от трёх столбцов по отдельности: день недели, месяц, год
# <br>- корректно изучить топ10 населённых пунктов с наибольшим числом объявлений
# <br>- корректно рассчитать стоимость каждого километра в последнем шаге
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> - не заполнять пропуски в столбцах с картографическими данными - исправлено
# - не заполнять пропуски в столбце days_exposition - исправлено
# - поправить границы для аномальных значений (высота потолка, площадь квартиры, стоимость, количество комнат) - везде перепроверила
# - изучить зависимость цены от трёх столбцов по отдельности: день недели, месяц, год - готово
# - корректно изучить топ10 населённых пунктов с наибольшим числом объявлений - готово
# - корректно рассчитать стоимость каждого километра в последнем шаге - исправлено
# - поправить выводы там, где это необходимо - дан :)
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v2:</b>
# <br>Остались 4 правки:
# <br>- поправить границы для аномальных значений (высота потолка, площадь квартиры, стоимость, количество комнат)
# <br>- поправить код, падающий с ошибкой
# <br>- изучить зависимость цены от трёх столбцов по отдельности: день недели, месяц, год
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
#
# - поправить границы для аномальных значений (высота потолка, площадь квартиры, стоимость, количество комнат) - готово!
#
# - поправить код, падающий с ошибкой - дан!
#
#
# - изучить зависимость цены от трёх столбцов по отдельности: день недели, месяц, год - сделано!
#
#
# - поправить выводы там, где это необходимо - есть!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v3:</b>
# <br>Все правки выполнены. Молодец!
# <br>Проделана огромная работа! У тебя подробные, понятные и логичные выводы, которые ты подкрепляешь фактами. Были использованы разные графики и способы, чтобы как можно более тщательно изучить данные и у тебя это получилось!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
